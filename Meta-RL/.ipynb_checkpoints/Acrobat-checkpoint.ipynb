# %%
import numpy as np
import os
import time
import gym
from collections import deque
import tensorflow as tf
import tensorflow.keras as K
from Agent import *

# %%
ENV_NAME = "Acrobot-v1"
TRAIN_ITERATIONS = 5000
MAX_EPISODE_LENGTH = 1000
TRAJECTORY_BUFFER_SIZE = 32
BATCH_SIZE = 16
RENDER_EVERY = 10

# %%
env = gym.make(ENV_NAME)
agent = Agent(env.action_space.n,env.observation_space.shape,BATCH_SIZE)
samples_filled = 0
# Out:
# WARNING:tensorflow:From C:\Users\Vinay Patel\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# state_input (InputLayer)     [(None, 6)]               0
# _________________________________________________________________
# dense1 (Dense)               (None, 32)                224
# _________________________________________________________________
# dense2 (Dense)               (None, 32)                1056
# _________________________________________________________________
# actor_output_layer (Dense)   (None, 1)                 33
# =================================================================
# Total params: 1,313
# Trainable params: 1,313
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# state_input (InputLayer)        [(None, 6)]          0
# __________________________________________________________________________________________________
# dense1 (Dense)                  (None, 32)           224         state_input[0][0]
# __________________________________________________________________________________________________
# dense2 (Dense)                  (None, 32)           1056        dense1[0][0]
# __________________________________________________________________________________________________
# advantage_input (InputLayer)    [(None, 1)]          0
# __________________________________________________________________________________________________
# old_prediction_input (InputLaye [(None, 3)]          0
# __________________________________________________________________________________________________
# actor_output_layer (Dense)      (None, 3)            99          dense2[0][0]
# ==================================================================================================
# Total params: 1,379
# Trainable params: 1,379
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# state_input (InputLayer)        [(None, 6)]          0
# __________________________________________________________________________________________________
# dense1 (Dense)                  (None, 32)           224         state_input[0][0]
# __________________________________________________________________________________________________
# dense2 (Dense)                  (None, 32)           1056        dense1[0][0]
# __________________________________________________________________________________________________
# advantage_input (InputLayer)    [(None, 1)]          0
# __________________________________________________________________________________________________
# old_prediction_input (InputLaye [(None, 3)]          0
# __________________________________________________________________________________________________
# actor_output_layer (Dense)      (None, 3)            99          dense2[0][0]
# ==================================================================================================
# Total params: 1,379
# Trainable params: 1,379
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
scores_window = deque(maxlen=100)
scores = []

for cnt_episode in range(TRAIN_ITERATIONS):
    s = env.reset()
    r_sum = 0
    for cnt_step in range(MAX_EPISODE_LENGTH):
        if cnt_episode % RENDER_EVERY == 0 :
            env.render()
        a = agent.choose_action(s)
        s_, r, done, _ = env.step(a)
        r_sum += r
        if done:
            r = -1
        agent.store_transition(s, a, s_, r, done)
        samples_filled += 1
        if samples_filled % TRAJECTORY_BUFFER_SIZE == 0 and samples_filled != 0:
            for _ in range(TRAJECTORY_BUFFER_SIZE // BATCH_SIZE):
                agent.train_network()
            agent.memory.clear()
            samples_filled = 0
        s = s_
        if done:
            break
    scores_window.append(r_sum)
    scores.append(r_sum)
    if np.mean(scores_window)>=-110:
        print('\nEnvironment solved in {:d} episodes!\tAverage Score: {:.2f}'.format(episode-100, np.mean(scores_window)))
        agent.actor_model.save_weights(str(episode_reward)+"acrobot_actor.h5")
        break
    max_reward = max(max_reward, episode_reward)
    print('Episodes:', cnt_episode, 'Episodic_Reweard:', r_sum, 'Max_Reward_Achieved:', max_reward)
# Out:
# WARNING:tensorflow:From C:\Users\Vinay Patel\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow_core\python\ops\math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Episode:0, step:499, r_sum:-4.999999999999938
# Episode:1, step:499, r_sum:-4.999999999999938
# Episode:2, step:499, r_sum:-4.999999999999938
# Episode:3, step:426, r_sum:-4.259999999999954
# Episode:4, step:485, r_sum:-4.849999999999941
# Episode:5, step:419, r_sum:-4.189999999999955
# Episode:6, step:499, r_sum:-4.999999999999938
# Episode:7, step:499, r_sum:-4.999999999999938
# Episode:8, step:499, r_sum:-4.999999999999938
# Episode:9, step:499, r_sum:-4.999999999999938
# Episode:10, step:499, r_sum:-4.999999999999938
# Episode:11, step:499, r_sum:-4.999999999999938
# Episode:12, step:499, r_sum:-4.999999999999938
# Episode:13, step:499, r_sum:-4.999999999999938
# Episode:14, step:499, r_sum:-4.999999999999938
# Episode:15, step:499, r_sum:-4.999999999999938
# Episode:16, step:499, r_sum:-4.999999999999938
# Episode:17, step:499, r_sum:-4.999999999999938
# Episode:18, step:499, r_sum:-4.999999999999938
# Episode:19, step:499, r_sum:-4.999999999999938
# Episode:20, step:499, r_sum:-4.999999999999938
# Episode:21, step:499, r_sum:-4.999999999999938
# Episode:22, step:320, r_sum:-3.1999999999999758
# Episode:23, step:499, r_sum:-4.999999999999938
# Episode:24, step:400, r_sum:-3.9999999999999587
# Episode:25, step:385, r_sum:-3.849999999999962
# Episode:26, step:482, r_sum:-4.819999999999942
# Episode:27, step:319, r_sum:-3.189999999999976
# Episode:28, step:499, r_sum:-4.999999999999938
# Episode:29, step:352, r_sum:-3.519999999999969
# Episode:30, step:436, r_sum:-4.3599999999999515
# Episode:31, step:424, r_sum:-4.239999999999954
# Episode:32, step:499, r_sum:-4.999999999999938
# Episode:33, step:499, r_sum:-4.999999999999938
# Episode:34, step:499, r_sum:-4.999999999999938
# Episode:35, step:499, r_sum:-4.999999999999938
# Episode:36, step:499, r_sum:-4.999999999999938
# Episode:37, step:499, r_sum:-4.999999999999938
# Episode:38, step:499, r_sum:-4.999999999999938
# Episode:39, step:499, r_sum:-4.999999999999938
# Episode:40, step:499, r_sum:-4.999999999999938
# Episode:41, step:493, r_sum:-4.929999999999939
# Episode:42, step:423, r_sum:-4.229999999999954
# Episode:43, step:499, r_sum:-4.999999999999938
# Episode:44, step:333, r_sum:-3.329999999999973
# Episode:45, step:336, r_sum:-3.3599999999999723
# Episode:46, step:278, r_sum:-2.7799999999999847
# Episode:47, step:213, r_sum:-2.1299999999999986
# Episode:48, step:380, r_sum:-3.799999999999963
# Episode:49, step:209, r_sum:-2.0899999999999994
# Episode:50, step:291, r_sum:-2.909999999999982
# Episode:51, step:251, r_sum:-2.5099999999999905
# Episode:52, step:264, r_sum:-2.6399999999999877
# Episode:53, step:227, r_sum:-2.2699999999999956
# Episode:54, step:288, r_sum:-2.8799999999999826
# Episode:55, step:324, r_sum:-3.239999999999975
# Episode:56, step:499, r_sum:-4.999999999999938
# Episode:57, step:499, r_sum:-4.999999999999938
# Episode:58, step:436, r_sum:-4.3599999999999515
# Episode:59, step:499, r_sum:-4.999999999999938
# Episode:60, step:499, r_sum:-4.999999999999938
# Episode:61, step:499, r_sum:-4.999999999999938
# Episode:62, step:499, r_sum:-4.999999999999938
# Episode:63, step:499, r_sum:-4.999999999999938
# Episode:64, step:499, r_sum:-4.999999999999938
# Episode:65, step:499, r_sum:-4.999999999999938
# Episode:66, step:499, r_sum:-4.999999999999938
# Episode:67, step:499, r_sum:-4.999999999999938
# Episode:68, step:499, r_sum:-4.999999999999938
# Episode:69, step:499, r_sum:-4.999999999999938
# Episode:70, step:499, r_sum:-4.999999999999938
# Episode:71, step:499, r_sum:-4.999999999999938
# Episode:72, step:499, r_sum:-4.999999999999938
# Episode:73, step:499, r_sum:-4.999999999999938
# Episode:74, step:499, r_sum:-4.999999999999938
# Episode:75, step:499, r_sum:-4.999999999999938
# Episode:76, step:499, r_sum:-4.999999999999938
# Episode:77, step:499, r_sum:-4.999999999999938
# Episode:78, step:499, r_sum:-4.999999999999938
# Episode:79, step:499, r_sum:-4.999999999999938
# Episode:80, step:499, r_sum:-4.999999999999938
# Episode:81, step:499, r_sum:-4.999999999999938
# Episode:82, step:499, r_sum:-4.999999999999938
# Episode:83, step:499, r_sum:-4.999999999999938
# Episode:84, step:499, r_sum:-4.999999999999938
# Episode:85, step:499, r_sum:-4.999999999999938
# Episode:86, step:499, r_sum:-4.999999999999938
# Episode:87, step:499, r_sum:-4.999999999999938
# Episode:88, step:499, r_sum:-4.999999999999938
# Episode:89, step:499, r_sum:-4.999999999999938
# Episode:90, step:499, r_sum:-4.999999999999938
# Episode:91, step:499, r_sum:-4.999999999999938
# Episode:92, step:499, r_sum:-4.999999999999938
# Episode:93, step:499, r_sum:-4.999999999999938
# Episode:94, step:499, r_sum:-4.999999999999938
# Episode:95, step:499, r_sum:-4.999999999999938
# Episode:96, step:499, r_sum:-4.999999999999938
# Episode:97, step:499, r_sum:-4.999999999999938
# Episode:98, step:499, r_sum:-4.999999999999938
# Episode:99, step:499, r_sum:-4.999999999999938
# Episode:100, step:499, r_sum:-4.999999999999938
# Episode:101, step:499, r_sum:-4.999999999999938
# Episode:102, step:499, r_sum:-4.999999999999938
# Episode:103, step:499, r_sum:-4.999999999999938
# Episode:104, step:499, r_sum:-4.999999999999938
# Episode:105, step:499, r_sum:-4.999999999999938
# Episode:106, step:499, r_sum:-4.999999999999938
# Episode:107, step:499, r_sum:-4.999999999999938
# Episode:108, step:499, r_sum:-4.999999999999938
# Episode:109, step:499, r_sum:-4.999999999999938
# Episode:110, step:499, r_sum:-4.999999999999938
# Episode:111, step:499, r_sum:-4.999999999999938
# Episode:112, step:499, r_sum:-4.999999999999938
# Episode:113, step:499, r_sum:-4.999999999999938
# Episode:114, step:499, r_sum:-4.999999999999938
# Episode:115, step:499, r_sum:-4.999999999999938
# Episode:116, step:499, r_sum:-4.999999999999938
# Episode:117, step:499, r_sum:-4.999999999999938
# Episode:118, step:499, r_sum:-4.999999999999938
# Episode:119, step:499, r_sum:-4.999999999999938
# Episode:120, step:499, r_sum:-4.999999999999938
# Episode:121, step:499, r_sum:-4.999999999999938
# Episode:122, step:499, r_sum:-4.999999999999938
# Episode:123, step:499, r_sum:-4.999999999999938
# Episode:124, step:499, r_sum:-4.999999999999938
# Episode:125, step:499, r_sum:-4.999999999999938
# Episode:126, step:499, r_sum:-4.999999999999938
# Episode:127, step:499, r_sum:-4.999999999999938
# Episode:128, step:499, r_sum:-4.999999999999938
# Episode:129, step:499, r_sum:-4.999999999999938
# Episode:130, step:499, r_sum:-4.999999999999938
# Episode:131, step:499, r_sum:-4.999999999999938
# Episode:132, step:499, r_sum:-4.999999999999938
# Episode:133, step:499, r_sum:-4.999999999999938
# Episode:134, step:499, r_sum:-4.999999999999938
# Episode:135, step:499, r_sum:-4.999999999999938
# Episode:136, step:499, r_sum:-4.999999999999938
# Episode:137, step:499, r_sum:-4.999999999999938
# Episode:138, step:499, r_sum:-4.999999999999938
# Episode:139, step:499, r_sum:-4.999999999999938
# Episode:140, step:499, r_sum:-4.999999999999938
# Episode:141, step:499, r_sum:-4.999999999999938
# Episode:142, step:499, r_sum:-4.999999999999938
# Episode:143, step:499, r_sum:-4.999999999999938
# Episode:144, step:499, r_sum:-4.999999999999938
# Episode:145, step:499, r_sum:-4.999999999999938
# Episode:146, step:499, r_sum:-4.999999999999938
# Episode:147, step:499, r_sum:-4.999999999999938
# Episode:148, step:499, r_sum:-4.999999999999938
# Episode:149, step:499, r_sum:-4.999999999999938
# Episode:150, step:499, r_sum:-4.999999999999938
# Episode:151, step:499, r_sum:-4.999999999999938
# Episode:152, step:499, r_sum:-4.999999999999938
# Episode:153, step:499, r_sum:-4.999999999999938
# Episode:154, step:499, r_sum:-4.999999999999938
# Episode:155, step:499, r_sum:-4.999999999999938
# Episode:156, step:499, r_sum:-4.999999999999938
# Episode:157, step:499, r_sum:-4.999999999999938
# Episode:158, step:499, r_sum:-4.999999999999938
# Episode:159, step:499, r_sum:-4.999999999999938
# Episode:160, step:499, r_sum:-4.999999999999938
# Episode:161, step:499, r_sum:-4.999999999999938
# Episode:162, step:499, r_sum:-4.999999999999938
# Episode:163, step:499, r_sum:-4.999999999999938
# Episode:164, step:499, r_sum:-4.999999999999938
# Episode:165, step:499, r_sum:-4.999999999999938
# Episode:166, step:499, r_sum:-4.999999999999938
# Episode:167, step:499, r_sum:-4.999999999999938
# Episode:168, step:499, r_sum:-4.999999999999938
# Episode:169, step:499, r_sum:-4.999999999999938
# Episode:170, step:499, r_sum:-4.999999999999938
# Episode:171, step:499, r_sum:-4.999999999999938
# Episode:172, step:499, r_sum:-4.999999999999938
# Episode:173, step:499, r_sum:-4.999999999999938
# Episode:174, step:499, r_sum:-4.999999999999938
# Episode:175, step:499, r_sum:-4.999999999999938
# Episode:176, step:499, r_sum:-4.999999999999938
# Episode:177, step:499, r_sum:-4.999999999999938
# Episode:178, step:499, r_sum:-4.999999999999938
# Episode:179, step:499, r_sum:-4.999999999999938
# Episode:180, step:499, r_sum:-4.999999999999938
# Episode:181, step:499, r_sum:-4.999999999999938
# Episode:182, step:499, r_sum:-4.999999999999938
# Episode:183, step:499, r_sum:-4.999999999999938
# Episode:184, step:499, r_sum:-4.999999999999938
# Episode:185, step:499, r_sum:-4.999999999999938
# Episode:186, step:499, r_sum:-4.999999999999938
# Episode:187, step:499, r_sum:-4.999999999999938
# Episode:188, step:499, r_sum:-4.999999999999938
# Episode:189, step:499, r_sum:-4.999999999999938
# Episode:190, step:499, r_sum:-4.999999999999938
# Episode:191, step:499, r_sum:-4.999999999999938
# Episode:192, step:499, r_sum:-4.999999999999938
# Episode:193, step:499, r_sum:-4.999999999999938
# Episode:194, step:499, r_sum:-4.999999999999938
# Episode:195, step:499, r_sum:-4.999999999999938
# Episode:196, step:499, r_sum:-4.999999999999938
# Episode:197, step:499, r_sum:-4.999999999999938
# Episode:198, step:499, r_sum:-4.999999999999938
# Episode:199, step:499, r_sum:-4.999999999999938
# Episode:200, step:499, r_sum:-4.999999999999938
# Episode:201, step:499, r_sum:-4.999999999999938
# Episode:202, step:499, r_sum:-4.999999999999938
# Episode:203, step:499, r_sum:-4.999999999999938
# Episode:204, step:499, r_sum:-4.999999999999938
# Episode:205, step:499, r_sum:-4.999999999999938
# Episode:206, step:499, r_sum:-4.999999999999938
# Episode:207, step:499, r_sum:-4.999999999999938
# Episode:208, step:499, r_sum:-4.999999999999938
# Episode:209, step:499, r_sum:-4.999999999999938
# Episode:210, step:499, r_sum:-4.999999999999938
# Episode:211, step:499, r_sum:-4.999999999999938
# Episode:212, step:499, r_sum:-4.999999999999938
# Episode:213, step:499, r_sum:-4.999999999999938
# Episode:214, step:499, r_sum:-4.999999999999938
# Episode:215, step:499, r_sum:-4.999999999999938
# Episode:216, step:499, r_sum:-4.999999999999938
# Episode:217, step:499, r_sum:-4.999999999999938
# Episode:218, step:499, r_sum:-4.999999999999938
# Episode:219, step:499, r_sum:-4.999999999999938
# Episode:220, step:499, r_sum:-4.999999999999938
# Episode:221, step:499, r_sum:-4.999999999999938
# Episode:222, step:499, r_sum:-4.999999999999938
# Episode:223, step:465, r_sum:-4.649999999999945
# Episode:224, step:499, r_sum:-4.999999999999938
# Episode:225, step:499, r_sum:-4.999999999999938
# Episode:226, step:499, r_sum:-4.999999999999938
# Episode:227, step:499, r_sum:-4.999999999999938
# Episode:228, step:499, r_sum:-4.999999999999938
# Episode:229, step:499, r_sum:-4.999999999999938
# Episode:230, step:499, r_sum:-4.999999999999938
# Episode:231, step:499, r_sum:-4.999999999999938
# Episode:232, step:499, r_sum:-4.999999999999938
# Episode:233, step:499, r_sum:-4.999999999999938
# Episode:234, step:499, r_sum:-4.999999999999938
# Episode:235, step:499, r_sum:-4.999999999999938
# Episode:236, step:499, r_sum:-4.999999999999938
# Episode:237, step:499, r_sum:-4.999999999999938
# Episode:238, step:499, r_sum:-4.999999999999938
# Episode:239, step:499, r_sum:-4.999999999999938
# Episode:240, step:499, r_sum:-4.999999999999938
# Episode:241, step:499, r_sum:-4.999999999999938
# Episode:242, step:499, r_sum:-4.999999999999938
# Episode:243, step:499, r_sum:-4.999999999999938
# Episode:244, step:499, r_sum:-4.999999999999938
# Episode:245, step:499, r_sum:-4.999999999999938
# Episode:246, step:499, r_sum:-4.999999999999938
# Episode:247, step:499, r_sum:-4.999999999999938
# Episode:248, step:499, r_sum:-4.999999999999938
# Episode:249, step:499, r_sum:-4.999999999999938
# Episode:250, step:499, r_sum:-4.999999999999938
# Episode:251, step:499, r_sum:-4.999999999999938
# Episode:252, step:499, r_sum:-4.999999999999938
# Episode:253, step:499, r_sum:-4.999999999999938
# Episode:254, step:499, r_sum:-4.999999999999938
# Episode:255, step:460, r_sum:-4.599999999999946
# Episode:256, step:499, r_sum:-4.999999999999938
# Episode:257, step:360, r_sum:-3.5999999999999672
# Episode:258, step:228, r_sum:-2.2799999999999954
# Episode:259, step:315, r_sum:-3.149999999999977
# Episode:260, step:443, r_sum:-4.42999999999995
# Episode:261, step:467, r_sum:-4.669999999999945
# Episode:262, step:350, r_sum:-3.4999999999999694
# Episode:263, step:285, r_sum:-2.849999999999983
# Episode:264, step:266, r_sum:-2.6599999999999873
# Episode:265, step:325, r_sum:-3.2499999999999747
# Episode:266, step:364, r_sum:-3.6399999999999664
# Episode:267, step:366, r_sum:-3.659999999999966
# Episode:268, step:304, r_sum:-3.039999999999979
# Episode:269, step:321, r_sum:-3.2099999999999755
# Episode:270, step:219, r_sum:-2.1899999999999973
# Episode:271, step:217, r_sum:-2.1699999999999977
# Episode:272, step:206, r_sum:-2.06
# Episode:273, step:433, r_sum:-4.329999999999952
# Episode:274, step:295, r_sum:-2.949999999999981
# Episode:275, step:304, r_sum:-3.039999999999979
# Episode:276, step:375, r_sum:-3.749999999999964
# Episode:277, step:445, r_sum:-4.4499999999999496
# Episode:278, step:447, r_sum:-4.469999999999949
# Episode:279, step:395, r_sum:-3.9499999999999598
# Episode:280, step:282, r_sum:-2.819999999999984
# Episode:281, step:487, r_sum:-4.869999999999941
# Episode:282, step:273, r_sum:-2.7299999999999858
# Episode:283, step:487, r_sum:-4.869999999999941
# Episode:284, step:499, r_sum:-4.999999999999938
# Episode:285, step:425, r_sum:-4.249999999999954
# Episode:286, step:461, r_sum:-4.609999999999946
# Episode:287, step:363, r_sum:-3.6299999999999666
# Episode:288, step:499, r_sum:-4.999999999999938
# Episode:289, step:365, r_sum:-3.649999999999966
# Episode:290, step:329, r_sum:-3.289999999999974
# Episode:291, step:389, r_sum:-3.889999999999961
# Episode:292, step:344, r_sum:-3.4399999999999706
# Episode:293, step:478, r_sum:-4.7799999999999425
# Episode:294, step:499, r_sum:-4.999999999999938
# Episode:295, step:442, r_sum:-4.41999999999995
# Episode:296, step:431, r_sum:-4.3099999999999525
# Episode:297, step:425, r_sum:-4.249999999999954
# Episode:298, step:497, r_sum:-4.9699999999999385
# Episode:299, step:499, r_sum:-4.999999999999938
# Episode:300, step:499, r_sum:-4.999999999999938
# Episode:301, step:499, r_sum:-4.999999999999938
# Episode:302, step:499, r_sum:-4.999999999999938
# Episode:303, step:499, r_sum:-4.999999999999938
# Episode:304, step:499, r_sum:-4.999999999999938
# Episode:305, step:499, r_sum:-4.999999999999938
# Episode:306, step:499, r_sum:-4.999999999999938
# Episode:307, step:499, r_sum:-4.999999999999938
# Episode:308, step:499, r_sum:-4.999999999999938
# Episode:309, step:406, r_sum:-4.059999999999958
# Episode:310, step:289, r_sum:-2.8899999999999824
# Episode:311, step:499, r_sum:-4.999999999999938
# Episode:312, step:499, r_sum:-4.999999999999938
# Episode:313, step:499, r_sum:-4.999999999999938
# Episode:314, step:479, r_sum:-4.789999999999942
# Episode:315, step:275, r_sum:-2.7499999999999853
# Episode:316, step:419, r_sum:-4.189999999999955
# Episode:317, step:363, r_sum:-3.6299999999999666
# Episode:318, step:425, r_sum:-4.249999999999954
# Episode:319, step:232, r_sum:-2.3199999999999945
# Episode:320, step:352, r_sum:-3.519999999999969
# Episode:321, step:302, r_sum:-3.0199999999999796
# Episode:322, step:417, r_sum:-4.1699999999999555
# Episode:323, step:499, r_sum:-4.999999999999938
# Episode:324, step:495, r_sum:-4.949999999999939
# Episode:325, step:424, r_sum:-4.239999999999954
# Episode:326, step:345, r_sum:-3.4499999999999704
# Episode:327, step:499, r_sum:-4.999999999999938
# Episode:328, step:499, r_sum:-4.999999999999938
# Episode:329, step:381, r_sum:-3.8099999999999627
# Episode:330, step:344, r_sum:-3.4399999999999706
# Episode:331, step:499, r_sum:-4.999999999999938
# Episode:332, step:351, r_sum:-3.509999999999969
# Episode:333, step:218, r_sum:-2.1799999999999975
# Episode:334, step:297, r_sum:-2.9699999999999807
# Episode:335, step:316, r_sum:-3.1599999999999766
# Episode:336, step:255, r_sum:-2.5499999999999896
# Episode:337, step:213, r_sum:-2.1299999999999986
# Episode:338, step:237, r_sum:-2.3699999999999934
# Episode:339, step:424, r_sum:-4.239999999999954
# Episode:340, step:222, r_sum:-2.2199999999999966
# Episode:341, step:278, r_sum:-2.7799999999999847
# Episode:342, step:363, r_sum:-3.6299999999999666
# Episode:343, step:200, r_sum:-2.0000000000000013
# Episode:344, step:287, r_sum:-2.869999999999983
# Episode:345, step:184, r_sum:-1.8400000000000014
# Episode:346, step:181, r_sum:-1.8100000000000014
# Episode:347, step:205, r_sum:-2.0500000000000003
# Episode:348, step:213, r_sum:-2.1299999999999986
# Episode:349, step:177, r_sum:-1.7700000000000014
# Episode:350, step:153, r_sum:-1.5300000000000011
# Episode:351, step:151, r_sum:-1.5100000000000011
# Episode:352, step:282, r_sum:-2.819999999999984
# Episode:353, step:149, r_sum:-1.490000000000001
# Episode:354, step:222, r_sum:-2.2199999999999966
# Episode:355, step:161, r_sum:-1.6100000000000012
# Episode:356, step:209, r_sum:-2.0899999999999994
# Episode:357, step:213, r_sum:-2.1299999999999986
# Episode:358, step:190, r_sum:-1.9000000000000015
# Episode:359, step:174, r_sum:-1.7400000000000013
# Episode:360, step:185, r_sum:-1.8500000000000014
# Episode:361, step:189, r_sum:-1.8900000000000015
# Episode:362, step:189, r_sum:-1.8900000000000015
# Episode:363, step:192, r_sum:-1.9200000000000015
# Episode:364, step:271, r_sum:-2.709999999999986
# Episode:365, step:298, r_sum:-2.9799999999999804
# Episode:366, step:227, r_sum:-2.2699999999999956
# Episode:367, step:210, r_sum:-2.099999999999999
# Episode:368, step:248, r_sum:-2.479999999999991
# Episode:369, step:156, r_sum:-1.5600000000000012
# Episode:370, step:164, r_sum:-1.6400000000000012
# Episode:371, step:323, r_sum:-3.229999999999975
# Episode:372, step:258, r_sum:-2.579999999999989
# Episode:373, step:375, r_sum:-3.749999999999964
# Episode:374, step:274, r_sum:-2.7399999999999856
# Episode:375, step:211, r_sum:-2.109999999999999
# Episode:376, step:262, r_sum:-2.619999999999988
# Episode:377, step:367, r_sum:-3.6699999999999657
# Episode:378, step:295, r_sum:-2.949999999999981
# Episode:379, step:309, r_sum:-3.089999999999978
# Episode:380, step:344, r_sum:-3.4399999999999706
# Episode:381, step:396, r_sum:-3.9599999999999596
# Episode:382, step:499, r_sum:-4.999999999999938
# Episode:383, step:499, r_sum:-4.999999999999938
# Episode:384, step:271, r_sum:-2.709999999999986
# Episode:385, step:304, r_sum:-3.039999999999979
# Episode:386, step:290, r_sum:-2.899999999999982
# Episode:387, step:424, r_sum:-4.239999999999954
# Episode:388, step:499, r_sum:-4.999999999999938
# Episode:389, step:395, r_sum:-3.9499999999999598
# Episode:390, step:308, r_sum:-3.0799999999999783
# Episode:391, step:287, r_sum:-2.869999999999983
# Episode:392, step:363, r_sum:-3.6299999999999666
# Episode:393, step:202, r_sum:-2.020000000000001
# Episode:394, step:315, r_sum:-3.149999999999977
# Episode:395, step:499, r_sum:-4.999999999999938
# Episode:396, step:437, r_sum:-4.369999999999951
# Episode:397, step:308, r_sum:-3.0799999999999783
# Episode:398, step:499, r_sum:-4.999999999999938
# Episode:399, step:256, r_sum:-2.5599999999999894
# Episode:400, step:224, r_sum:-2.239999999999996
# Episode:401, step:333, r_sum:-3.329999999999973
# Episode:402, step:242, r_sum:-2.4199999999999924
# Episode:403, step:331, r_sum:-3.3099999999999734
# Episode:404, step:379, r_sum:-3.789999999999963
# Episode:405, step:499, r_sum:-4.999999999999938
# Episode:406, step:499, r_sum:-4.999999999999938
# Episode:407, step:499, r_sum:-4.999999999999938
# Episode:408, step:323, r_sum:-3.229999999999975
# Episode:409, step:393, r_sum:-3.92999999999996
# Episode:410, step:499, r_sum:-4.999999999999938
# Episode:411, step:499, r_sum:-4.999999999999938
# Episode:412, step:445, r_sum:-4.4499999999999496
# Episode:413, step:499, r_sum:-4.999999999999938
# Episode:414, step:370, r_sum:-3.699999999999965
# Episode:415, step:499, r_sum:-4.999999999999938
# Episode:416, step:499, r_sum:-4.999999999999938
# Episode:417, step:499, r_sum:-4.999999999999938
# Episode:418, step:499, r_sum:-4.999999999999938
# Episode:419, step:465, r_sum:-4.649999999999945
# Episode:420, step:499, r_sum:-4.999999999999938
# Episode:421, step:499, r_sum:-4.999999999999938
# Episode:422, step:499, r_sum:-4.999999999999938
# Episode:423, step:499, r_sum:-4.999999999999938
# Episode:424, step:226, r_sum:-2.259999999999996
# Episode:425, step:499, r_sum:-4.999999999999938
# Episode:426, step:311, r_sum:-3.1099999999999777
# Episode:427, step:348, r_sum:-3.47999999999997
# Episode:428, step:314, r_sum:-3.139999999999977
# Episode:429, step:254, r_sum:-2.53999999999999
# Episode:430, step:297, r_sum:-2.9699999999999807
# Episode:431, step:302, r_sum:-3.0199999999999796
# Episode:432, step:269, r_sum:-2.6899999999999866
# Episode:433, step:373, r_sum:-3.7299999999999645
# Episode:434, step:362, r_sum:-3.619999999999967
# Episode:435, step:204, r_sum:-2.0400000000000005
# Episode:436, step:219, r_sum:-2.1899999999999973
# Episode:437, step:379, r_sum:-3.789999999999963
# Episode:438, step:171, r_sum:-1.7100000000000013
# Episode:439, step:200, r_sum:-2.0000000000000013
# Episode:440, step:225, r_sum:-2.249999999999996
# Episode:441, step:166, r_sum:-1.6600000000000013
# Episode:442, step:381, r_sum:-3.8099999999999627
# Episode:443, step:185, r_sum:-1.8500000000000014
# Episode:444, step:217, r_sum:-2.1699999999999977
# Episode:445, step:355, r_sum:-3.5499999999999683
# Episode:446, step:258, r_sum:-2.579999999999989
# Episode:447, step:278, r_sum:-2.7799999999999847
# Episode:448, step:213, r_sum:-2.1299999999999986
# Episode:449, step:267, r_sum:-2.669999999999987
# Episode:450, step:275, r_sum:-2.7499999999999853
# Episode:451, step:169, r_sum:-1.6900000000000013
# Episode:452, step:239, r_sum:-2.389999999999993
# Episode:453, step:199, r_sum:-1.9900000000000015
# Episode:454, step:284, r_sum:-2.8399999999999834
# Episode:455, step:403, r_sum:-4.0299999999999585
# Episode:456, step:214, r_sum:-2.1399999999999983
# Episode:457, step:267, r_sum:-2.669999999999987
# Episode:458, step:220, r_sum:-2.199999999999997
# Episode:459, step:288, r_sum:-2.8799999999999826
# Episode:460, step:204, r_sum:-2.0400000000000005
# Episode:461, step:427, r_sum:-4.269999999999953
# Episode:462, step:211, r_sum:-2.109999999999999
# Episode:463, step:340, r_sum:-3.3999999999999715
# Episode:464, step:340, r_sum:-3.3999999999999715
# Episode:465, step:270, r_sum:-2.6999999999999864
# Episode:466, step:286, r_sum:-2.859999999999983
# Episode:467, step:229, r_sum:-2.289999999999995
# Episode:468, step:336, r_sum:-3.3599999999999723
# Episode:469, step:282, r_sum:-2.819999999999984
# Episode:470, step:379, r_sum:-3.789999999999963
# Episode:471, step:146, r_sum:-1.460000000000001
# Episode:472, step:211, r_sum:-2.109999999999999
# Episode:473, step:268, r_sum:-2.679999999999987
# Episode:474, step:178, r_sum:-1.7800000000000014
# Episode:475, step:220, r_sum:-2.199999999999997
# Episode:476, step:255, r_sum:-2.5499999999999896
# Episode:477, step:367, r_sum:-3.6699999999999657
# Episode:478, step:499, r_sum:-4.999999999999938
# Episode:479, step:325, r_sum:-3.2499999999999747
# Episode:480, step:200, r_sum:-2.0000000000000013
# Episode:481, step:363, r_sum:-3.6299999999999666
# Episode:482, step:296, r_sum:-2.959999999999981
# Episode:483, step:209, r_sum:-2.0899999999999994
# Episode:484, step:183, r_sum:-1.8300000000000014
# Episode:485, step:205, r_sum:-2.0500000000000003
# Episode:486, step:165, r_sum:-1.6500000000000012
# Episode:487, step:189, r_sum:-1.8900000000000015
# Episode:488, step:206, r_sum:-2.06
# Episode:489, step:170, r_sum:-1.7000000000000013
# Episode:490, step:208, r_sum:-2.0799999999999996
# Episode:491, step:124, r_sum:-1.2400000000000009
# Episode:492, step:284, r_sum:-2.8399999999999834
# Episode:493, step:167, r_sum:-1.6700000000000013
# Episode:494, step:187, r_sum:-1.8700000000000014
# Episode:495, step:499, r_sum:-4.999999999999938
# Episode:496, step:190, r_sum:-1.9000000000000015
# Episode:497, step:154, r_sum:-1.5400000000000011
# Episode:498, step:121, r_sum:-1.2100000000000009
# Episode:499, step:137, r_sum:-1.370000000000001
# Episode:500, step:128, r_sum:-1.280000000000001
# Episode:501, step:100, r_sum:-1.0000000000000007
# Episode:502, step:125, r_sum:-1.2500000000000009
# Episode:503, step:137, r_sum:-1.370000000000001
# Episode:504, step:124, r_sum:-1.2400000000000009
# Episode:505, step:160, r_sum:-1.6000000000000012
# Episode:506, step:206, r_sum:-2.06
# Episode:507, step:127, r_sum:-1.270000000000001
# Episode:508, step:114, r_sum:-1.1400000000000008
# Episode:509, step:111, r_sum:-1.1100000000000008
# Episode:510, step:178, r_sum:-1.7800000000000014
# Episode:511, step:141, r_sum:-1.410000000000001
# Episode:512, step:124, r_sum:-1.2400000000000009
# Episode:513, step:113, r_sum:-1.1300000000000008
# Episode:514, step:113, r_sum:-1.1300000000000008
# Episode:515, step:122, r_sum:-1.2200000000000009
# Episode:516, step:140, r_sum:-1.400000000000001
# Episode:517, step:108, r_sum:-1.0800000000000007
# Episode:518, step:134, r_sum:-1.340000000000001
# Episode:519, step:105, r_sum:-1.0500000000000007
# Episode:520, step:168, r_sum:-1.6800000000000013
# Episode:521, step:131, r_sum:-1.310000000000001
# Episode:522, step:162, r_sum:-1.6200000000000012
# Episode:523, step:164, r_sum:-1.6400000000000012
# Episode:524, step:168, r_sum:-1.6800000000000013
# Episode:525, step:184, r_sum:-1.8400000000000014
# Episode:526, step:156, r_sum:-1.5600000000000012
# Episode:527, step:207, r_sum:-2.07
# Episode:528, step:229, r_sum:-2.289999999999995
# Episode:529, step:214, r_sum:-2.1399999999999983
# Episode:530, step:150, r_sum:-1.500000000000001
# Episode:531, step:151, r_sum:-1.5100000000000011
# Episode:532, step:192, r_sum:-1.9200000000000015
# Episode:533, step:214, r_sum:-2.1399999999999983
# Episode:534, step:146, r_sum:-1.460000000000001
# Episode:535, step:167, r_sum:-1.6700000000000013
# Episode:536, step:140, r_sum:-1.400000000000001
# Episode:537, step:121, r_sum:-1.2100000000000009
# Episode:538, step:155, r_sum:-1.5500000000000012
# Episode:539, step:140, r_sum:-1.400000000000001
# Episode:540, step:181, r_sum:-1.8100000000000014
# Episode:541, step:178, r_sum:-1.7800000000000014
# Episode:542, step:142, r_sum:-1.420000000000001
# Episode:543, step:186, r_sum:-1.8600000000000014
# Episode:544, step:142, r_sum:-1.420000000000001
# Episode:545, step:132, r_sum:-1.320000000000001
# Episode:546, step:206, r_sum:-2.06
# Episode:547, step:196, r_sum:-1.9600000000000015
# Episode:548, step:148, r_sum:-1.480000000000001
# Episode:549, step:267, r_sum:-2.669999999999987
# Episode:550, step:117, r_sum:-1.1700000000000008
# Episode:551, step:279, r_sum:-2.7899999999999845
# Episode:552, step:174, r_sum:-1.7400000000000013
# Episode:553, step:167, r_sum:-1.6700000000000013
# Episode:554, step:146, r_sum:-1.460000000000001
# Episode:555, step:188, r_sum:-1.8800000000000014
# Episode:556, step:203, r_sum:-2.0300000000000007
# Episode:557, step:194, r_sum:-1.9400000000000015
# Episode:558, step:183, r_sum:-1.8300000000000014
# Episode:559, step:184, r_sum:-1.8400000000000014
# Episode:560, step:155, r_sum:-1.5500000000000012
# Episode:561, step:189, r_sum:-1.8900000000000015
# Episode:562, step:170, r_sum:-1.7000000000000013
# Episode:563, step:270, r_sum:-2.6999999999999864
# Episode:564, step:211, r_sum:-2.109999999999999
# Episode:565, step:217, r_sum:-2.1699999999999977
# Episode:566, step:334, r_sum:-3.3399999999999728
# Episode:567, step:345, r_sum:-3.4499999999999704
# Episode:568, step:180, r_sum:-1.8000000000000014
# Episode:569, step:328, r_sum:-3.279999999999974
# Episode:570, step:141, r_sum:-1.410000000000001
# Episode:571, step:205, r_sum:-2.0500000000000003
# Episode:572, step:215, r_sum:-2.149999999999998
# Episode:573, step:224, r_sum:-2.239999999999996
# Episode:574, step:193, r_sum:-1.9300000000000015
# Episode:575, step:200, r_sum:-2.0000000000000013
# Episode:576, step:154, r_sum:-1.5400000000000011
# Episode:577, step:220, r_sum:-2.199999999999997
# Episode:578, step:344, r_sum:-3.4399999999999706
# Episode:579, step:285, r_sum:-2.849999999999983
# Episode:580, step:211, r_sum:-2.109999999999999
# Episode:581, step:266, r_sum:-2.6599999999999873
# Episode:582, step:142, r_sum:-1.420000000000001
# Episode:583, step:207, r_sum:-2.07
# Episode:584, step:178, r_sum:-1.7800000000000014
# Episode:585, step:220, r_sum:-2.199999999999997
# Episode:586, step:186, r_sum:-1.8600000000000014
# Episode:587, step:134, r_sum:-1.340000000000001
# Episode:588, step:119, r_sum:-1.1900000000000008
# Episode:589, step:225, r_sum:-2.249999999999996
# Episode:590, step:142, r_sum:-1.420000000000001
# Episode:591, step:143, r_sum:-1.430000000000001
# Episode:592, step:136, r_sum:-1.360000000000001
# Episode:593, step:135, r_sum:-1.350000000000001
# Episode:594, step:209, r_sum:-2.0899999999999994
# Episode:595, step:159, r_sum:-1.5900000000000012
# Episode:596, step:244, r_sum:-2.439999999999992
# Episode:597, step:155, r_sum:-1.5500000000000012
# Episode:598, step:192, r_sum:-1.9200000000000015
# Episode:599, step:278, r_sum:-2.7799999999999847
# Episode:600, step:158, r_sum:-1.5800000000000012
# Episode:601, step:182, r_sum:-1.8200000000000014
# Episode:602, step:189, r_sum:-1.8900000000000015
# Episode:603, step:150, r_sum:-1.500000000000001
# Episode:604, step:148, r_sum:-1.480000000000001
# Episode:605, step:148, r_sum:-1.480000000000001
# Episode:606, step:228, r_sum:-2.2799999999999954
# Episode:607, step:203, r_sum:-2.0300000000000007
# Episode:608, step:215, r_sum:-2.149999999999998
# Episode:609, step:141, r_sum:-1.410000000000001
# Episode:610, step:163, r_sum:-1.6300000000000012
# Episode:611, step:146, r_sum:-1.460000000000001
# Episode:612, step:170, r_sum:-1.7000000000000013
# Episode:613, step:256, r_sum:-2.5599999999999894
# Episode:614, step:214, r_sum:-2.1399999999999983
# Episode:615, step:179, r_sum:-1.7900000000000014
# Episode:616, step:499, r_sum:-4.999999999999938
# Episode:617, step:457, r_sum:-4.569999999999947
# Episode:618, step:209, r_sum:-2.0899999999999994
# Episode:619, step:190, r_sum:-1.9000000000000015
# Episode:620, step:111, r_sum:-1.1100000000000008
# Episode:621, step:190, r_sum:-1.9000000000000015
# Episode:622, step:233, r_sum:-2.3299999999999943
# Episode:623, step:212, r_sum:-2.1199999999999988
# Episode:624, step:172, r_sum:-1.7200000000000013
# Episode:625, step:246, r_sum:-2.4599999999999915
# Episode:626, step:178, r_sum:-1.7800000000000014
# Episode:627, step:181, r_sum:-1.8100000000000014
# Episode:628, step:206, r_sum:-2.06
# Episode:629, step:177, r_sum:-1.7700000000000014
# Episode:630, step:276, r_sum:-2.759999999999985
# Episode:631, step:287, r_sum:-2.869999999999983
# Episode:632, step:202, r_sum:-2.020000000000001
# Episode:633, step:183, r_sum:-1.8300000000000014
# Episode:634, step:308, r_sum:-3.0799999999999783
# Episode:635, step:163, r_sum:-1.6300000000000012
# Episode:636, step:236, r_sum:-2.3599999999999937
# Episode:637, step:238, r_sum:-2.3799999999999932
# Episode:638, step:499, r_sum:-4.989999999999938
# Episode:639, step:235, r_sum:-2.349999999999994
# Episode:640, step:146, r_sum:-1.460000000000001
# Episode:641, step:207, r_sum:-2.07
# Episode:642, step:233, r_sum:-2.3299999999999943
# Episode:643, step:280, r_sum:-2.7999999999999843
# Episode:644, step:216, r_sum:-2.159999999999998
# Episode:645, step:177, r_sum:-1.7700000000000014
# Episode:646, step:139, r_sum:-1.390000000000001
# Episode:647, step:250, r_sum:-2.4999999999999907
# Episode:648, step:208, r_sum:-2.0799999999999996
# Episode:649, step:231, r_sum:-2.3099999999999947
# Episode:650, step:260, r_sum:-2.5999999999999885
# Episode:651, step:204, r_sum:-2.0400000000000005
# Episode:652, step:172, r_sum:-1.7200000000000013
# Episode:653, step:202, r_sum:-2.020000000000001
# Episode:654, step:204, r_sum:-2.0400000000000005
# Episode:655, step:229, r_sum:-2.289999999999995
# Episode:656, step:131, r_sum:-1.310000000000001
# Episode:657, step:135, r_sum:-1.350000000000001
# Episode:658, step:183, r_sum:-1.8300000000000014
# Episode:659, step:173, r_sum:-1.7300000000000013
# Episode:660, step:158, r_sum:-1.5800000000000012
# Episode:661, step:173, r_sum:-1.7300000000000013
# Episode:662, step:213, r_sum:-2.1299999999999986
# Episode:663, step:175, r_sum:-1.7500000000000013
# Episode:664, step:164, r_sum:-1.6400000000000012
# Episode:665, step:133, r_sum:-1.330000000000001
# Episode:666, step:129, r_sum:-1.290000000000001
# Episode:667, step:256, r_sum:-2.5599999999999894
# Episode:668, step:159, r_sum:-1.5900000000000012
# Episode:669, step:208, r_sum:-2.0799999999999996
# Episode:670, step:189, r_sum:-1.8900000000000015
# Episode:671, step:126, r_sum:-1.260000000000001
# Episode:672, step:150, r_sum:-1.500000000000001
# Episode:673, step:149, r_sum:-1.490000000000001
# Episode:674, step:141, r_sum:-1.410000000000001
# Episode:675, step:195, r_sum:-1.9500000000000015
# Episode:676, step:224, r_sum:-2.239999999999996
# Episode:677, step:173, r_sum:-1.7300000000000013
# Episode:678, step:115, r_sum:-1.1500000000000008
# Episode:679, step:176, r_sum:-1.7600000000000013
# Episode:680, step:124, r_sum:-1.2400000000000009
# Episode:681, step:143, r_sum:-1.430000000000001
# Episode:682, step:279, r_sum:-2.7899999999999845
# Episode:683, step:165, r_sum:-1.6500000000000012
# Episode:684, step:208, r_sum:-2.0799999999999996
# Episode:685, step:201, r_sum:-2.010000000000001
# Episode:686, step:123, r_sum:-1.2300000000000009
# Episode:687, step:194, r_sum:-1.9400000000000015
# Episode:688, step:133, r_sum:-1.330000000000001
# Episode:689, step:187, r_sum:-1.8700000000000014
# Episode:690, step:217, r_sum:-2.1699999999999977
# Episode:691, step:184, r_sum:-1.8400000000000014
# Episode:692, step:230, r_sum:-2.299999999999995
# Episode:693, step:206, r_sum:-2.06
# Episode:694, step:126, r_sum:-1.260000000000001
# Episode:695, step:168, r_sum:-1.6800000000000013
# Episode:696, step:198, r_sum:-1.9800000000000015
# Episode:697, step:145, r_sum:-1.450000000000001
# Episode:698, step:188, r_sum:-1.8800000000000014
# Episode:699, step:173, r_sum:-1.7300000000000013
# Episode:700, step:163, r_sum:-1.6300000000000012
# Episode:701, step:151, r_sum:-1.5100000000000011
# Episode:702, step:148, r_sum:-1.480000000000001
# Episode:703, step:138, r_sum:-1.380000000000001
# Episode:704, step:147, r_sum:-1.470000000000001
# Episode:705, step:215, r_sum:-2.149999999999998
# Episode:706, step:226, r_sum:-2.259999999999996
# Episode:707, step:118, r_sum:-1.1800000000000008
# Episode:708, step:211, r_sum:-2.109999999999999
# Episode:709, step:119, r_sum:-1.1900000000000008
# Episode:710, step:145, r_sum:-1.450000000000001
# Episode:711, step:135, r_sum:-1.350000000000001
# Episode:712, step:160, r_sum:-1.6000000000000012
# Episode:713, step:191, r_sum:-1.9100000000000015
# Episode:714, step:157, r_sum:-1.5700000000000012
# Episode:715, step:499, r_sum:-4.999999999999938
# Episode:716, step:130, r_sum:-1.300000000000001
# Episode:717, step:201, r_sum:-2.010000000000001
# Episode:718, step:174, r_sum:-1.7400000000000013
# Episode:719, step:124, r_sum:-1.2400000000000009
# Episode:720, step:200, r_sum:-2.0000000000000013
# Episode:721, step:135, r_sum:-1.350000000000001
# Episode:722, step:188, r_sum:-1.8800000000000014
# Episode:723, step:143, r_sum:-1.430000000000001
# Episode:724, step:190, r_sum:-1.9000000000000015
# Episode:725, step:224, r_sum:-2.239999999999996
# Episode:726, step:153, r_sum:-1.5300000000000011
# Episode:727, step:126, r_sum:-1.260000000000001
# Episode:728, step:146, r_sum:-1.460000000000001
# Episode:729, step:160, r_sum:-1.6000000000000012
# Episode:730, step:121, r_sum:-1.2100000000000009
# Episode:731, step:145, r_sum:-1.450000000000001
# Episode:732, step:224, r_sum:-2.239999999999996
# Episode:733, step:128, r_sum:-1.280000000000001
# Episode:734, step:165, r_sum:-1.6500000000000012
# Episode:735, step:158, r_sum:-1.5800000000000012
# Episode:736, step:124, r_sum:-1.2400000000000009
# Episode:737, step:158, r_sum:-1.5800000000000012
# Episode:738, step:138, r_sum:-1.380000000000001
# Episode:739, step:115, r_sum:-1.1500000000000008
# Episode:740, step:123, r_sum:-1.2300000000000009
# Episode:741, step:150, r_sum:-1.500000000000001
# Episode:742, step:125, r_sum:-1.2500000000000009
# Episode:743, step:134, r_sum:-1.340000000000001
# Episode:744, step:140, r_sum:-1.400000000000001
# Episode:745, step:275, r_sum:-2.7499999999999853
# Episode:746, step:115, r_sum:-1.1500000000000008
# Episode:747, step:120, r_sum:-1.2000000000000008
# Episode:748, step:127, r_sum:-1.270000000000001
# Episode:749, step:221, r_sum:-2.209999999999997
# Episode:750, step:209, r_sum:-2.0899999999999994
# Episode:751, step:134, r_sum:-1.340000000000001
# Episode:752, step:163, r_sum:-1.6300000000000012
# Episode:753, step:123, r_sum:-1.2300000000000009
# Episode:754, step:152, r_sum:-1.5200000000000011
# Episode:755, step:175, r_sum:-1.7500000000000013
# Episode:756, step:187, r_sum:-1.8700000000000014
# Episode:757, step:127, r_sum:-1.270000000000001
# Episode:758, step:241, r_sum:-2.4099999999999926
# Episode:759, step:140, r_sum:-1.400000000000001
# Episode:760, step:99, r_sum:-0.9900000000000007
# Episode:761, step:123, r_sum:-1.2300000000000009
# Episode:762, step:211, r_sum:-2.109999999999999
# Episode:763, step:144, r_sum:-1.440000000000001
# Episode:764, step:111, r_sum:-1.1100000000000008
# Episode:765, step:127, r_sum:-1.270000000000001
# Episode:766, step:114, r_sum:-1.1400000000000008
# Episode:767, step:129, r_sum:-1.290000000000001
# Episode:768, step:145, r_sum:-1.450000000000001
# Episode:769, step:115, r_sum:-1.1500000000000008
# Episode:770, step:106, r_sum:-1.0600000000000007
# Episode:771, step:119, r_sum:-1.1900000000000008
# Episode:772, step:135, r_sum:-1.350000000000001
# Episode:773, step:120, r_sum:-1.2000000000000008
# Episode:774, step:151, r_sum:-1.5100000000000011
# Episode:775, step:174, r_sum:-1.7400000000000013
# Episode:776, step:93, r_sum:-0.9300000000000006
# Episode:777, step:147, r_sum:-1.470000000000001
# Episode:778, step:136, r_sum:-1.360000000000001
# Episode:779, step:111, r_sum:-1.1100000000000008
# Episode:780, step:151, r_sum:-1.5100000000000011
# Episode:781, step:113, r_sum:-1.1300000000000008
# Episode:782, step:126, r_sum:-1.260000000000001
# Episode:783, step:175, r_sum:-1.7500000000000013
# Episode:784, step:119, r_sum:-1.1900000000000008
# Episode:785, step:131, r_sum:-1.310000000000001
# Episode:786, step:105, r_sum:-1.0500000000000007
# Episode:787, step:109, r_sum:-1.0900000000000007
# Episode:788, step:112, r_sum:-1.1200000000000008
# Episode:789, step:131, r_sum:-1.310000000000001
# Episode:790, step:101, r_sum:-1.0100000000000007
# Episode:791, step:89, r_sum:-0.8900000000000006
# Episode:792, step:123, r_sum:-1.2300000000000009
# Episode:793, step:107, r_sum:-1.0700000000000007
# Episode:794, step:122, r_sum:-1.2200000000000009
# Episode:795, step:132, r_sum:-1.320000000000001
# Episode:796, step:115, r_sum:-1.1500000000000008
# Episode:797, step:96, r_sum:-0.9600000000000006
# Episode:798, step:129, r_sum:-1.290000000000001
# Episode:799, step:156, r_sum:-1.5600000000000012
# Episode:800, step:109, r_sum:-1.0900000000000007
# Episode:801, step:135, r_sum:-1.350000000000001
# Episode:802, step:157, r_sum:-1.5700000000000012
# Episode:803, step:104, r_sum:-1.0400000000000007
# Episode:804, step:108, r_sum:-1.0800000000000007
# Episode:805, step:117, r_sum:-1.1700000000000008
# Episode:806, step:109, r_sum:-1.0900000000000007
# Episode:807, step:115, r_sum:-1.1500000000000008
# Episode:808, step:157, r_sum:-1.5700000000000012
# Episode:809, step:229, r_sum:-2.289999999999995
# Episode:810, step:114, r_sum:-1.1400000000000008
# Episode:811, step:99, r_sum:-0.9900000000000007
# Episode:812, step:94, r_sum:-0.9400000000000006
# Episode:813, step:130, r_sum:-1.300000000000001
# Episode:814, step:123, r_sum:-1.2300000000000009
# Episode:815, step:93, r_sum:-0.9300000000000006
# Episode:816, step:119, r_sum:-1.1900000000000008
# Episode:817, step:80, r_sum:-0.8000000000000005
# Episode:818, step:145, r_sum:-1.450000000000001
# Episode:819, step:130, r_sum:-1.300000000000001
# Episode:820, step:101, r_sum:-1.0100000000000007
# Episode:821, step:105, r_sum:-1.0500000000000007
# Episode:822, step:225, r_sum:-2.249999999999996
# Episode:823, step:104, r_sum:-1.0400000000000007
# Episode:824, step:121, r_sum:-1.2100000000000009
# Episode:825, step:97, r_sum:-0.9700000000000006
# Episode:826, step:116, r_sum:-1.1600000000000008
# Episode:827, step:123, r_sum:-1.2300000000000009
# Episode:828, step:118, r_sum:-1.1800000000000008
# Episode:829, step:138, r_sum:-1.380000000000001
# Episode:830, step:156, r_sum:-1.5600000000000012
# Episode:831, step:202, r_sum:-2.020000000000001
# Episode:832, step:115, r_sum:-1.1500000000000008
# Episode:833, step:147, r_sum:-1.470000000000001
# Episode:834, step:140, r_sum:-1.400000000000001
# Episode:835, step:99, r_sum:-0.9900000000000007
# Episode:836, step:183, r_sum:-1.8300000000000014
# Episode:837, step:121, r_sum:-1.2100000000000009
# Episode:838, step:96, r_sum:-0.9600000000000006
# Episode:839, step:97, r_sum:-0.9700000000000006
# Episode:840, step:114, r_sum:-1.1400000000000008
# Episode:841, step:110, r_sum:-1.1000000000000008
# Episode:842, step:113, r_sum:-1.1300000000000008
# Episode:843, step:144, r_sum:-1.440000000000001
# Episode:844, step:171, r_sum:-1.7100000000000013
# Episode:845, step:127, r_sum:-1.270000000000001
# Episode:846, step:129, r_sum:-1.290000000000001
# Episode:847, step:137, r_sum:-1.370000000000001
# Episode:848, step:118, r_sum:-1.1800000000000008
# Episode:849, step:102, r_sum:-1.0200000000000007
# Episode:850, step:116, r_sum:-1.1600000000000008
# Episode:851, step:153, r_sum:-1.5300000000000011
# Episode:852, step:139, r_sum:-1.390000000000001
# Episode:853, step:206, r_sum:-2.06
# Episode:854, step:225, r_sum:-2.249999999999996
# Episode:855, step:127, r_sum:-1.270000000000001
# Episode:856, step:123, r_sum:-1.2300000000000009
# Episode:857, step:105, r_sum:-1.0500000000000007
# Episode:858, step:129, r_sum:-1.290000000000001
# Episode:859, step:139, r_sum:-1.390000000000001
# Episode:860, step:121, r_sum:-1.2100000000000009
# Episode:861, step:96, r_sum:-0.9600000000000006
# Episode:862, step:106, r_sum:-1.0600000000000007
# Episode:863, step:115, r_sum:-1.1500000000000008
# Episode:864, step:118, r_sum:-1.1800000000000008
# Episode:865, step:132, r_sum:-1.320000000000001
# Episode:866, step:121, r_sum:-1.2100000000000009
# Episode:867, step:97, r_sum:-0.9700000000000006
# Episode:868, step:139, r_sum:-1.390000000000001
# Episode:869, step:170, r_sum:-1.7000000000000013
# Episode:870, step:107, r_sum:-1.0700000000000007
# Episode:871, step:164, r_sum:-1.6400000000000012
# Episode:872, step:112, r_sum:-1.1200000000000008
# Episode:873, step:147, r_sum:-1.470000000000001
# Episode:874, step:139, r_sum:-1.390000000000001
# Episode:875, step:107, r_sum:-1.0700000000000007
# Episode:876, step:147, r_sum:-1.470000000000001
# Episode:877, step:127, r_sum:-1.270000000000001
# Episode:878, step:108, r_sum:-1.0800000000000007
# Episode:879, step:239, r_sum:-2.389999999999993
# Episode:880, step:122, r_sum:-1.2200000000000009
# Episode:881, step:111, r_sum:-1.1100000000000008
# Episode:882, step:113, r_sum:-1.1300000000000008
# Episode:883, step:150, r_sum:-1.500000000000001
# Episode:884, step:130, r_sum:-1.300000000000001
# Episode:885, step:150, r_sum:-1.500000000000001
# Episode:886, step:127, r_sum:-1.270000000000001
# Episode:887, step:140, r_sum:-1.400000000000001
# Episode:888, step:126, r_sum:-1.260000000000001
# Episode:889, step:119, r_sum:-1.1900000000000008
# Episode:890, step:137, r_sum:-1.370000000000001
# Episode:891, step:130, r_sum:-1.300000000000001
# Episode:892, step:122, r_sum:-1.2200000000000009
# Episode:893, step:152, r_sum:-1.5200000000000011
# Episode:894, step:166, r_sum:-1.6600000000000013
# Episode:895, step:133, r_sum:-1.330000000000001
# Episode:896, step:250, r_sum:-2.4999999999999907
# Episode:897, step:195, r_sum:-1.9500000000000015
# Episode:898, step:188, r_sum:-1.8800000000000014
# Episode:899, step:157, r_sum:-1.5700000000000012
# Episode:900, step:179, r_sum:-1.7900000000000014
# Episode:901, step:129, r_sum:-1.290000000000001
# Episode:902, step:156, r_sum:-1.5600000000000012
# Episode:903, step:137, r_sum:-1.370000000000001
# Episode:904, step:273, r_sum:-2.7299999999999858
# Episode:905, step:119, r_sum:-1.1900000000000008
# Episode:906, step:206, r_sum:-2.06
# Episode:907, step:137, r_sum:-1.370000000000001
# Episode:908, step:144, r_sum:-1.440000000000001
# Episode:909, step:185, r_sum:-1.8500000000000014
# Episode:910, step:165, r_sum:-1.6500000000000012
# Episode:911, step:135, r_sum:-1.350000000000001
# Episode:912, step:189, r_sum:-1.8900000000000015
# Episode:913, step:184, r_sum:-1.8400000000000014
# Episode:914, step:156, r_sum:-1.5600000000000012
# Episode:915, step:221, r_sum:-2.209999999999997
# Episode:916, step:149, r_sum:-1.490000000000001
# Episode:917, step:213, r_sum:-2.1299999999999986
# Episode:918, step:151, r_sum:-1.5100000000000011
# Episode:919, step:200, r_sum:-2.0000000000000013
# Episode:920, step:189, r_sum:-1.8900000000000015
# Episode:921, step:170, r_sum:-1.7000000000000013
# Episode:922, step:271, r_sum:-2.709999999999986
# Episode:923, step:143, r_sum:-1.430000000000001
# Episode:924, step:177, r_sum:-1.7700000000000014
# Episode:925, step:278, r_sum:-2.7799999999999847
# Episode:926, step:176, r_sum:-1.7600000000000013
# Episode:927, step:131, r_sum:-1.310000000000001
# Episode:928, step:192, r_sum:-1.9200000000000015
# Episode:929, step:169, r_sum:-1.6900000000000013
# Episode:930, step:177, r_sum:-1.7700000000000014
# Episode:931, step:195, r_sum:-1.9500000000000015
# Episode:932, step:180, r_sum:-1.8000000000000014
# Episode:933, step:144, r_sum:-1.440000000000001
# Episode:934, step:159, r_sum:-1.5900000000000012
# Episode:935, step:155, r_sum:-1.5500000000000012
# Episode:936, step:132, r_sum:-1.320000000000001
# Episode:937, step:156, r_sum:-1.5600000000000012
# Episode:938, step:158, r_sum:-1.5800000000000012
# Episode:939, step:143, r_sum:-1.430000000000001
# Episode:940, step:160, r_sum:-1.6000000000000012
# Episode:941, step:181, r_sum:-1.8100000000000014
# Episode:942, step:240, r_sum:-2.399999999999993
# Episode:943, step:182, r_sum:-1.8200000000000014
# Episode:944, step:154, r_sum:-1.5400000000000011
# Episode:945, step:285, r_sum:-2.849999999999983
# Episode:946, step:155, r_sum:-1.5500000000000012
# Episode:947, step:106, r_sum:-1.0600000000000007
# Episode:948, step:123, r_sum:-1.2300000000000009
# Episode:949, step:146, r_sum:-1.460000000000001
# Episode:950, step:104, r_sum:-1.0400000000000007
# Episode:951, step:200, r_sum:-2.0000000000000013
# Episode:952, step:218, r_sum:-2.1799999999999975
# Episode:953, step:125, r_sum:-1.2500000000000009
# Episode:954, step:218, r_sum:-2.1799999999999975
# Episode:955, step:158, r_sum:-1.5800000000000012
# Episode:956, step:108, r_sum:-1.0800000000000007
# Episode:957, step:146, r_sum:-1.460000000000001
# Episode:958, step:186, r_sum:-1.8600000000000014
# Episode:959, step:147, r_sum:-1.470000000000001
# Episode:960, step:159, r_sum:-1.5900000000000012
# Episode:961, step:144, r_sum:-1.440000000000001
# Episode:962, step:161, r_sum:-1.6100000000000012
# Episode:963, step:123, r_sum:-1.2300000000000009
# Episode:964, step:158, r_sum:-1.5800000000000012
# Episode:965, step:156, r_sum:-1.5600000000000012
# Episode:966, step:113, r_sum:-1.1300000000000008
# Episode:967, step:134, r_sum:-1.340000000000001
# Episode:968, step:144, r_sum:-1.440000000000001
# Episode:969, step:142, r_sum:-1.420000000000001
# Episode:970, step:124, r_sum:-1.2400000000000009
# Episode:971, step:165, r_sum:-1.6500000000000012
# Episode:972, step:105, r_sum:-1.0500000000000007
# Episode:973, step:169, r_sum:-1.6900000000000013
# Episode:974, step:173, r_sum:-1.7300000000000013
# Episode:975, step:103, r_sum:-1.0300000000000007
# Episode:976, step:145, r_sum:-1.450000000000001
# Episode:977, step:147, r_sum:-1.470000000000001
# Episode:978, step:128, r_sum:-1.280000000000001
# Episode:979, step:225, r_sum:-2.249999999999996
# Episode:980, step:115, r_sum:-1.1500000000000008
# Episode:981, step:184, r_sum:-1.8400000000000014
# Episode:982, step:170, r_sum:-1.7000000000000013
# Episode:983, step:206, r_sum:-2.06
# Episode:984, step:137, r_sum:-1.370000000000001
# Episode:985, step:177, r_sum:-1.7700000000000014
# Episode:986, step:106, r_sum:-1.0600000000000007
# Episode:987, step:176, r_sum:-1.7600000000000013
# Episode:988, step:214, r_sum:-2.1399999999999983
# ...
# Episode:1419, step:499, r_sum:-4.999999999999938
# Episode:1420, step:499, r_sum:-4.999999999999938
# Episode:1421, step:499, r_sum:-4.999999999999938
# Episode:1422, step:499, r_sum:-4.999999999999938
# Episode:1423, step:499, r_sum:-4.999999999999938
# Episode:1424, step:499, r_sum:-4.999999999999938
# Episode:1425, step:499, r_sum:-4.999999999999938
# Episode:1426, step:499, r_sum:-4.999999999999938
# Episode:1427, step:499, r_sum:-4.999999999999938
# Episode:1428, step:499, r_sum:-4.999999999999938
# Episode:1429, step:499, r_sum:-4.999999999999938
# Episode:1430, step:499, r_sum:-4.999999999999938
# Episode:1431, step:499, r_sum:-4.999999999999938
# Episode:1432, step:499, r_sum:-4.999999999999938
# Episode:1433, step:499, r_sum:-4.999999999999938
# Episode:1434, step:499, r_sum:-4.999999999999938
# Episode:1435, step:499, r_sum:-4.999999999999938
# Episode:1436, step:499, r_sum:-4.999999999999938
# Episode:1437, step:499, r_sum:-4.999999999999938
# Episode:1438, step:499, r_sum:-4.999999999999938
# Episode:1439, step:499, r_sum:-4.999999999999938
# Episode:1440, step:499, r_sum:-4.999999999999938
# Episode:1441, step:499, r_sum:-4.999999999999938
# Episode:1442, step:499, r_sum:-4.999999999999938
# Episode:1443, step:499, r_sum:-4.999999999999938
# Episode:1444, step:499, r_sum:-4.999999999999938
# Episode:1445, step:499, r_sum:-4.999999999999938
# Episode:1446, step:499, r_sum:-4.999999999999938
# Episode:1447, step:499, r_sum:-4.999999999999938
# Episode:1448, step:499, r_sum:-4.999999999999938
# Episode:1449, step:499, r_sum:-4.999999999999938
# Episode:1450, step:499, r_sum:-4.999999999999938
# Episode:1451, step:499, r_sum:-4.999999999999938
# Episode:1452, step:499, r_sum:-4.999999999999938
# Episode:1453, step:499, r_sum:-4.999999999999938
# Episode:1454, step:499, r_sum:-4.999999999999938
# Episode:1455, step:499, r_sum:-4.999999999999938
# Episode:1456, step:499, r_sum:-4.999999999999938
# Episode:1457, step:499, r_sum:-4.999999999999938
# Episode:1458, step:499, r_sum:-4.999999999999938
# Episode:1459, step:499, r_sum:-4.999999999999938
# Episode:1460, step:499, r_sum:-4.999999999999938
# Episode:1461, step:499, r_sum:-4.999999999999938
# Episode:1462, step:499, r_sum:-4.999999999999938
# Episode:1463, step:499, r_sum:-4.999999999999938
# Episode:1464, step:499, r_sum:-4.999999999999938
# Episode:1465, step:499, r_sum:-4.999999999999938
# Episode:1466, step:499, r_sum:-4.999999999999938
# Episode:1467, step:499, r_sum:-4.999999999999938
# Episode:1468, step:499, r_sum:-4.999999999999938
# Episode:1469, step:499, r_sum:-4.999999999999938
# Episode:1470, step:499, r_sum:-4.999999999999938
# Episode:1471, step:499, r_sum:-4.999999999999938
# Episode:1472, step:499, r_sum:-4.999999999999938
# Episode:1473, step:499, r_sum:-4.999999999999938
# Episode:1474, step:499, r_sum:-4.999999999999938
# Episode:1475, step:499, r_sum:-4.999999999999938
# Episode:1476, step:499, r_sum:-4.999999999999938
# Episode:1477, step:499, r_sum:-4.999999999999938
# Episode:1478, step:499, r_sum:-4.999999999999938
# Episode:1479, step:499, r_sum:-4.999999999999938
# Episode:1480, step:499, r_sum:-4.999999999999938
# Episode:1481, step:499, r_sum:-4.999999999999938
# Episode:1482, step:499, r_sum:-4.999999999999938
# Episode:1483, step:499, r_sum:-4.999999999999938
# Episode:1484, step:499, r_sum:-4.999999999999938
# Episode:1485, step:499, r_sum:-4.999999999999938
# Episode:1486, step:499, r_sum:-4.999999999999938
# Episode:1487, step:499, r_sum:-4.999999999999938
# Episode:1488, step:499, r_sum:-4.999999999999938
# Episode:1489, step:499, r_sum:-4.999999999999938
# Episode:1490, step:499, r_sum:-4.999999999999938
# Episode:1491, step:499, r_sum:-4.999999999999938
# Episode:1492, step:499, r_sum:-4.999999999999938
# Episode:1493, step:499, r_sum:-4.999999999999938
# Episode:1494, step:499, r_sum:-4.999999999999938
# Episode:1495, step:499, r_sum:-4.999999999999938
# Episode:1496, step:499, r_sum:-4.999999999999938
# Episode:1497, step:499, r_sum:-4.999999999999938
# Episode:1498, step:499, r_sum:-4.999999999999938
# Episode:1499, step:499, r_sum:-4.999999999999938
# Episode:1500, step:499, r_sum:-4.999999999999938
# Episode:1501, step:499, r_sum:-4.999999999999938
# Episode:1502, step:499, r_sum:-4.999999999999938
# Episode:1503, step:499, r_sum:-4.999999999999938
# Episode:1504, step:499, r_sum:-4.999999999999938
# Episode:1505, step:499, r_sum:-4.999999999999938
# Episode:1506, step:499, r_sum:-4.999999999999938
# Episode:1507, step:499, r_sum:-4.999999999999938
# Episode:1508, step:499, r_sum:-4.999999999999938
# Episode:1509, step:499, r_sum:-4.999999999999938
# Episode:1510, step:499, r_sum:-4.999999999999938
# Episode:1511, step:499, r_sum:-4.999999999999938
# Episode:1512, step:499, r_sum:-4.999999999999938
# Episode:1513, step:499, r_sum:-4.999999999999938
# Episode:1514, step:499, r_sum:-4.999999999999938
# Episode:1515, step:499, r_sum:-4.999999999999938
# Episode:1516, step:499, r_sum:-4.999999999999938
# Episode:1517, step:499, r_sum:-4.999999999999938
# Episode:1518, step:499, r_sum:-4.999999999999938
# Episode:1519, step:499, r_sum:-4.999999999999938
# Episode:1520, step:499, r_sum:-4.999999999999938
# Episode:1521, step:499, r_sum:-4.999999999999938
# Episode:1522, step:499, r_sum:-4.999999999999938
# Episode:1523, step:499, r_sum:-4.999999999999938
# Episode:1524, step:499, r_sum:-4.999999999999938
# Episode:1525, step:499, r_sum:-4.999999999999938
# Episode:1526, step:499, r_sum:-4.999999999999938
# Episode:1527, step:499, r_sum:-4.999999999999938
# Episode:1528, step:499, r_sum:-4.999999999999938
# Episode:1529, step:499, r_sum:-4.999999999999938
# Episode:1530, step:499, r_sum:-4.999999999999938
# Episode:1531, step:499, r_sum:-4.999999999999938
# Episode:1532, step:499, r_sum:-4.999999999999938
# Episode:1533, step:499, r_sum:-4.999999999999938
# Episode:1534, step:499, r_sum:-4.999999999999938
# Episode:1535, step:499, r_sum:-4.999999999999938
# Episode:1536, step:499, r_sum:-4.999999999999938
# Episode:1537, step:499, r_sum:-4.999999999999938
# Episode:1538, step:499, r_sum:-4.999999999999938
# Episode:1539, step:499, r_sum:-4.999999999999938
# Episode:1540, step:499, r_sum:-4.999999999999938
# Episode:1541, step:499, r_sum:-4.999999999999938
# Episode:1542, step:499, r_sum:-4.999999999999938
# Episode:1543, step:499, r_sum:-4.999999999999938
# Episode:1544, step:499, r_sum:-4.999999999999938
# Episode:1545, step:499, r_sum:-4.999999999999938
# Episode:1546, step:499, r_sum:-4.999999999999938
# Episode:1547, step:499, r_sum:-4.999999999999938
# Episode:1548, step:499, r_sum:-4.999999999999938
# Episode:1549, step:499, r_sum:-4.999999999999938
# Episode:1550, step:499, r_sum:-4.999999999999938
# Episode:1551, step:499, r_sum:-4.999999999999938
# Episode:1552, step:499, r_sum:-4.999999999999938
# Episode:1553, step:499, r_sum:-4.999999999999938
# Episode:1554, step:499, r_sum:-4.999999999999938
# Episode:1555, step:499, r_sum:-4.999999999999938
# Episode:1556, step:499, r_sum:-4.999999999999938
# Episode:1557, step:499, r_sum:-4.999999999999938
# Episode:1558, step:499, r_sum:-4.999999999999938
# Episode:1559, step:499, r_sum:-4.999999999999938
# Episode:1560, step:499, r_sum:-4.999999999999938
# Episode:1561, step:499, r_sum:-4.999999999999938
# Episode:1562, step:499, r_sum:-4.999999999999938
# Episode:1563, step:499, r_sum:-4.999999999999938
# Episode:1564, step:499, r_sum:-4.999999999999938
# Episode:1565, step:499, r_sum:-4.999999999999938
# Episode:1566, step:499, r_sum:-4.999999999999938
# Episode:1567, step:499, r_sum:-4.999999999999938
# Episode:1568, step:499, r_sum:-4.999999999999938
# Episode:1569, step:499, r_sum:-4.999999999999938
# Episode:1570, step:499, r_sum:-4.999999999999938
# Episode:1571, step:499, r_sum:-4.999999999999938
# Episode:1572, step:499, r_sum:-4.999999999999938
# Episode:1573, step:499, r_sum:-4.999999999999938
# Episode:1574, step:499, r_sum:-4.999999999999938
# Episode:1575, step:499, r_sum:-4.999999999999938
# Episode:1576, step:499, r_sum:-4.999999999999938
# Episode:1577, step:499, r_sum:-4.999999999999938
# Episode:1578, step:499, r_sum:-4.999999999999938
# Episode:1579, step:499, r_sum:-4.999999999999938
# Episode:1580, step:499, r_sum:-4.999999999999938
# Episode:1581, step:499, r_sum:-4.999999999999938
# Episode:1582, step:499, r_sum:-4.999999999999938
# Episode:1583, step:499, r_sum:-4.999999999999938
# Episode:1584, step:499, r_sum:-4.999999999999938
# Episode:1585, step:499, r_sum:-4.999999999999938
# Episode:1586, step:499, r_sum:-4.999999999999938
# Episode:1587, step:499, r_sum:-4.999999999999938
# Episode:1588, step:499, r_sum:-4.999999999999938
# Episode:1589, step:499, r_sum:-4.999999999999938
# Episode:1590, step:499, r_sum:-4.999999999999938
# Episode:1591, step:499, r_sum:-4.999999999999938
# Episode:1592, step:499, r_sum:-4.999999999999938
# Episode:1593, step:499, r_sum:-4.999999999999938
# Episode:1594, step:499, r_sum:-4.999999999999938
# Episode:1595, step:499, r_sum:-4.999999999999938
# Episode:1596, step:499, r_sum:-4.999999999999938
# Episode:1597, step:499, r_sum:-4.999999999999938
# Episode:1598, step:499, r_sum:-4.999999999999938
# Episode:1599, step:499, r_sum:-4.999999999999938
# Episode:1600, step:499, r_sum:-4.999999999999938
# Episode:1601, step:499, r_sum:-4.999999999999938
# Episode:1602, step:499, r_sum:-4.999999999999938
# Episode:1603, step:499, r_sum:-4.999999999999938
# Episode:1604, step:499, r_sum:-4.999999999999938
# Episode:1605, step:499, r_sum:-4.999999999999938
# Episode:1606, step:499, r_sum:-4.999999999999938
# Episode:1607, step:499, r_sum:-4.999999999999938
# Episode:1608, step:499, r_sum:-4.999999999999938
# Episode:1609, step:499, r_sum:-4.999999999999938
# Episode:1610, step:499, r_sum:-4.999999999999938
# Episode:1611, step:499, r_sum:-4.999999999999938
# Episode:1612, step:499, r_sum:-4.999999999999938
# Episode:1613, step:499, r_sum:-4.999999999999938
# Episode:1614, step:499, r_sum:-4.999999999999938
# Episode:1615, step:499, r_sum:-4.999999999999938
# Episode:1616, step:499, r_sum:-4.999999999999938
# Episode:1617, step:499, r_sum:-4.999999999999938
# Episode:1618, step:499, r_sum:-4.999999999999938
# Episode:1619, step:499, r_sum:-4.999999999999938
# Episode:1620, step:499, r_sum:-4.999999999999938
# Episode:1621, step:499, r_sum:-4.999999999999938
# Episode:1622, step:499, r_sum:-4.999999999999938
# Episode:1623, step:499, r_sum:-4.999999999999938
# Episode:1624, step:499, r_sum:-4.999999999999938
# Episode:1625, step:499, r_sum:-4.999999999999938
# Episode:1626, step:499, r_sum:-4.999999999999938
# Episode:1627, step:499, r_sum:-4.999999999999938
# Episode:1628, step:499, r_sum:-4.999999999999938
# Episode:1629, step:499, r_sum:-4.999999999999938
# Episode:1630, step:499, r_sum:-4.999999999999938
# Episode:1631, step:499, r_sum:-4.999999999999938
# Episode:1632, step:499, r_sum:-4.999999999999938
# Episode:1633, step:499, r_sum:-4.999999999999938
# Episode:1634, step:499, r_sum:-4.999999999999938
# Episode:1635, step:499, r_sum:-4.999999999999938
# Episode:1636, step:499, r_sum:-4.999999999999938
# Episode:1637, step:499, r_sum:-4.999999999999938
# Episode:1638, step:499, r_sum:-4.999999999999938
# Episode:1639, step:499, r_sum:-4.999999999999938
# Episode:1640, step:499, r_sum:-4.999999999999938
# Episode:1641, step:499, r_sum:-4.999999999999938
# Episode:1642, step:499, r_sum:-4.999999999999938
# Episode:1643, step:499, r_sum:-4.999999999999938
# Episode:1644, step:499, r_sum:-4.999999999999938
# Episode:1645, step:499, r_sum:-4.999999999999938
# Episode:1646, step:499, r_sum:-4.999999999999938
# Episode:1647, step:499, r_sum:-4.999999999999938
# Episode:1648, step:499, r_sum:-4.999999999999938
# Episode:1649, step:499, r_sum:-4.999999999999938
# Episode:1650, step:499, r_sum:-4.999999999999938
# Episode:1651, step:499, r_sum:-4.999999999999938
# Episode:1652, step:499, r_sum:-4.999999999999938
# Episode:1653, step:499, r_sum:-4.999999999999938
# Episode:1654, step:499, r_sum:-4.999999999999938
# Episode:1655, step:499, r_sum:-4.999999999999938
# Episode:1656, step:499, r_sum:-4.999999999999938
# Episode:1657, step:499, r_sum:-4.999999999999938
# Episode:1658, step:499, r_sum:-4.999999999999938
# Episode:1659, step:499, r_sum:-4.999999999999938
# Episode:1660, step:499, r_sum:-4.999999999999938
# Episode:1661, step:499, r_sum:-4.999999999999938
# Episode:1662, step:499, r_sum:-4.999999999999938
# Episode:1663, step:499, r_sum:-4.999999999999938
# Episode:1664, step:499, r_sum:-4.999999999999938
# Episode:1665, step:499, r_sum:-4.999999999999938
# Episode:1666, step:499, r_sum:-4.999999999999938
# Episode:1667, step:499, r_sum:-4.999999999999938
# Episode:1668, step:499, r_sum:-4.999999999999938
# Episode:1669, step:499, r_sum:-4.999999999999938
# Episode:1670, step:499, r_sum:-4.999999999999938
# Episode:1671, step:499, r_sum:-4.999999999999938
# Episode:1672, step:499, r_sum:-4.999999999999938
# Episode:1673, step:499, r_sum:-4.999999999999938
# Episode:1674, step:499, r_sum:-4.999999999999938
# Episode:1675, step:499, r_sum:-4.999999999999938
# Episode:1676, step:499, r_sum:-4.999999999999938
# Episode:1677, step:499, r_sum:-4.999999999999938
# Episode:1678, step:499, r_sum:-4.999999999999938
# Episode:1679, step:499, r_sum:-4.999999999999938
# Episode:1680, step:499, r_sum:-4.999999999999938
# Episode:1681, step:499, r_sum:-4.999999999999938
# Episode:1682, step:499, r_sum:-4.999999999999938
# Episode:1683, step:499, r_sum:-4.999999999999938
# Episode:1684, step:499, r_sum:-4.999999999999938
# Episode:1685, step:499, r_sum:-4.999999999999938
# Episode:1686, step:499, r_sum:-4.999999999999938
# Episode:1687, step:499, r_sum:-4.999999999999938
# Episode:1688, step:499, r_sum:-4.999999999999938
# Episode:1689, step:499, r_sum:-4.999999999999938
# Episode:1690, step:499, r_sum:-4.999999999999938
# Episode:1691, step:499, r_sum:-4.999999999999938
# Episode:1692, step:499, r_sum:-4.999999999999938
# Episode:1693, step:499, r_sum:-4.999999999999938
# Episode:1694, step:499, r_sum:-4.999999999999938
# Episode:1695, step:499, r_sum:-4.999999999999938
# Episode:1696, step:499, r_sum:-4.999999999999938
# Episode:1697, step:499, r_sum:-4.999999999999938
# Episode:1698, step:499, r_sum:-4.999999999999938
# Episode:1699, step:499, r_sum:-4.999999999999938
# Episode:1700, step:499, r_sum:-4.999999999999938
# Episode:1701, step:499, r_sum:-4.999999999999938
# Episode:1702, step:499, r_sum:-4.999999999999938
# Episode:1703, step:499, r_sum:-4.999999999999938
# Episode:1704, step:499, r_sum:-4.999999999999938
# Episode:1705, step:499, r_sum:-4.999999999999938
# Episode:1706, step:499, r_sum:-4.999999999999938
# Episode:1707, step:499, r_sum:-4.999999999999938
# Episode:1708, step:499, r_sum:-4.999999999999938
# Episode:1709, step:499, r_sum:-4.999999999999938
# Episode:1710, step:499, r_sum:-4.999999999999938
# Episode:1711, step:499, r_sum:-4.999999999999938
# Episode:1712, step:499, r_sum:-4.999999999999938
# Episode:1713, step:499, r_sum:-4.999999999999938
# Episode:1714, step:499, r_sum:-4.999999999999938
# Episode:1715, step:499, r_sum:-4.999999999999938
# Episode:1716, step:499, r_sum:-4.999999999999938
# Episode:1717, step:499, r_sum:-4.999999999999938
# Episode:1718, step:499, r_sum:-4.999999999999938
# Episode:1719, step:499, r_sum:-4.999999999999938
# Episode:1720, step:499, r_sum:-4.999999999999938
# Episode:1721, step:499, r_sum:-4.999999999999938
# Episode:1722, step:499, r_sum:-4.999999999999938
# Episode:1723, step:499, r_sum:-4.999999999999938
# Episode:1724, step:499, r_sum:-4.999999999999938
# Episode:1725, step:499, r_sum:-4.999999999999938
# Episode:1726, step:499, r_sum:-4.999999999999938
# Episode:1727, step:499, r_sum:-4.999999999999938
# Episode:1728, step:499, r_sum:-4.999999999999938
# Episode:1729, step:499, r_sum:-4.999999999999938
# Episode:1730, step:499, r_sum:-4.999999999999938
# Episode:1731, step:499, r_sum:-4.999999999999938
# Episode:1732, step:499, r_sum:-4.999999999999938
# Episode:1733, step:499, r_sum:-4.999999999999938
# Episode:1734, step:499, r_sum:-4.999999999999938
# Episode:1735, step:499, r_sum:-4.999999999999938
# Episode:1736, step:499, r_sum:-4.999999999999938
# Episode:1737, step:499, r_sum:-4.999999999999938
# Episode:1738, step:499, r_sum:-4.999999999999938
# Episode:1739, step:499, r_sum:-4.999999999999938
# Episode:1740, step:499, r_sum:-4.999999999999938
# Episode:1741, step:499, r_sum:-4.999999999999938
# Episode:1742, step:499, r_sum:-4.999999999999938
# Episode:1743, step:499, r_sum:-4.999999999999938
# Episode:1744, step:499, r_sum:-4.999999999999938
