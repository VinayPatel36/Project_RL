# %%
import numpy as np
import os
import time
import gym
from collections import deque
import tensorflow as tf
import tensorflow.keras as K
from Agent import *

# %%
ENV_NAME = "Acrobot-v1"
TRAIN_ITERATIONS = 5000
MAX_EPISODE_LENGTH = 1000
TRAJECTORY_BUFFER_SIZE = 32
BATCH_SIZE = 16
RENDER_EVERY = 1

# %%
env = gym.make(ENV_NAME)
agent = Agent(env.action_space.n,env.observation_space.shape,BATCH_SIZE)
samples_filled = 0
# Out:
# WARNING:tensorflow:From C:\Users\Vinay Patel\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# state_input (InputLayer)     [(None, 6)]               0
# _________________________________________________________________
# dense1 (Dense)               (None, 32)                224
# _________________________________________________________________
# dense2 (Dense)               (None, 32)                1056
# _________________________________________________________________
# actor_output_layer (Dense)   (None, 1)                 33
# =================================================================
# Total params: 1,313
# Trainable params: 1,313
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# state_input (InputLayer)        [(None, 6)]          0
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims (TensorF [(1, None, 6)]       0           state_input[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     (None, 24)           2976        tf_op_layer_ExpandDims[0][0]
# __________________________________________________________________________________________________
# dense1 (Dense)                  (None, 32)           800         lstm[0][0]
# __________________________________________________________________________________________________
# dense2 (Dense)                  (None, 32)           1056        dense1[0][0]
# __________________________________________________________________________________________________
# advantage_input (InputLayer)    [(None, 1)]          0
# __________________________________________________________________________________________________
# old_prediction_input (InputLaye [(None, 3)]          0
# __________________________________________________________________________________________________
# actor_output_layer (Dense)      (None, 3)            99          dense2[0][0]
# ==================================================================================================
# Total params: 4,931
# Trainable params: 4,931
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# state_input (InputLayer)        [(None, 6)]          0
# __________________________________________________________________________________________________
# tf_op_layer_ExpandDims_1 (Tenso [(1, None, 6)]       0           state_input[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (None, 24)           2976        tf_op_layer_ExpandDims_1[0][0]
# __________________________________________________________________________________________________
# dense1 (Dense)                  (None, 32)           800         lstm_1[0][0]
# __________________________________________________________________________________________________
# dense2 (Dense)                  (None, 32)           1056        dense1[0][0]
# __________________________________________________________________________________________________
# advantage_input (InputLayer)    [(None, 1)]          0
# __________________________________________________________________________________________________
# old_prediction_input (InputLaye [(None, 3)]          0
# __________________________________________________________________________________________________
# actor_output_layer (Dense)      (None, 3)            99          dense2[0][0]
# ==================================================================================================
# Total params: 4,931
# Trainable params: 4,931
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
scores_window = deque(maxlen=100)
scores = []
max_reward = -500
for cnt_episode in range(TRAIN_ITERATIONS):
    s = env.reset()
    r_sum = 0
    for cnt_step in range(MAX_EPISODE_LENGTH):
        if cnt_episode % RENDER_EVERY == 0 :
            env.render()
        a = agent.choose_action(s)
        s_, r, done, _ = env.step(a)
        r_sum += r
        agent.store_transition(s, a, s_, r, done)
        samples_filled += 1
        if samples_filled % TRAJECTORY_BUFFER_SIZE == 0 and samples_filled != 0:
            for _ in range(TRAJECTORY_BUFFER_SIZE // BATCH_SIZE):
                agent.train_network()
            agent.memory.clear()
            samples_filled = 0
        s = s_
        if done:
            break
    scores_window.append(r_sum)
    scores.append(r_sum)
    if np.mean(scores_window)>=-110:
        print('\nEnvironment solved in {:d} episodes!\tAverage Score: {:.2f}'.format(cnt_episode-100, np.mean(scores_window)))
        agent.actor_network.save_weights(str(r_sum)+"acrobot_actor.h5")
        break
    max_reward = max(max_reward, r_sum)
    print('Episodes:', cnt_episode, 'Episodic_Reweard:', r_sum, 'Max_Reward_Achieved:', max_reward)
# Out:
# WARNING:tensorflow:From C:\Users\Vinay Patel\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow_core\python\ops\math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
#
# Episodes: 156 Episodic_Reweard: -336.0 Max_Reward_Achieved: -225.0
# Episodes: 157 Episodic_Reweard: -364.0 Max_Reward_Achieved: -225.0
# Episodes: 158 Episodic_Reweard: -334.0 Max_Reward_Achieved: -225.0
# Episodes: 159 Episodic_Reweard: -475.0 Max_Reward_Achieved: -225.0
# Episodes: 160 Episodic_Reweard: -435.0 Max_Reward_Achieved: -225.0
# Episodes: 161 Episodic_Reweard: -441.0 Max_Reward_Achieved: -225.0
# Episodes: 162 Episodic_Reweard: -416.0 Max_Reward_Achieved: -225.0
# Episodes: 163 Episodic_Reweard: -448.0 Max_Reward_Achieved: -225.0
# Episodes: 164 Episodic_Reweard: -367.0 Max_Reward_Achieved: -225.0
# Episodes: 165 Episodic_Reweard: -500.0 Max_Reward_Achieved: -225.0
# Episodes: 166 Episodic_Reweard: -500.0 Max_Reward_Achieved: -225.0
# Episodes: 167 Episodic_Reweard: -500.0 Max_Reward_Achieved: -225.0
# Episodes: 168 Episodic_Reweard: -500.0 Max_Reward_Achieved: -225.0
# Episodes: 169 Episodic_Reweard: -500.0 Max_Reward_Achieved: -225.0
# Episodes: 170 Episodic_Reweard: -364.0 Max_Reward_Achieved: -225.0
# Episodes: 171 Episodic_Reweard: -500.0 Max_Reward_Achieved: -225.0
# Episodes: 172 Episodic_Reweard: -500.0 Max_Reward_Achieved: -225.0
# Episodes: 173 Episodic_Reweard: -413.0 Max_Reward_Achieved: -225.0
# Episodes: 174 Episodic_Reweard: -458.0 Max_Reward_Achieved: -225.0
# Episodes: 175 Episodic_Reweard: -297.0 Max_Reward_Achieved: -225.0
# Episodes: 176 Episodic_Reweard: -468.0 Max_Reward_Achieved: -225.0
# Episodes: 177 Episodic_Reweard: -488.0 Max_Reward_Achieved: -225.0
# Episodes: 178 Episodic_Reweard: -374.0 Max_Reward_Achieved: -225.0
# Episodes: 179 Episodic_Reweard: -374.0 Max_Reward_Achieved: -225.0
# Episodes: 180 Episodic_Reweard: -241.0 Max_Reward_Achieved: -225.0
# Episodes: 181 Episodic_Reweard: -363.0 Max_Reward_Achieved: -225.0
# Episodes: 182 Episodic_Reweard: -374.0 Max_Reward_Achieved: -225.0
# Episodes: 183 Episodic_Reweard: -232.0 Max_Reward_Achieved: -225.0
# Episodes: 184 Episodic_Reweard: -385.0 Max_Reward_Achieved: -225.0
# Episodes: 185 Episodic_Reweard: -377.0 Max_Reward_Achieved: -225.0
# Episodes: 186 Episodic_Reweard: -253.0 Max_Reward_Achieved: -225.0
# Episodes: 187 Episodic_Reweard: -313.0 Max_Reward_Achieved: -225.0
# Episodes: 188 Episodic_Reweard: -240.0 Max_Reward_Achieved: -225.0
# Episodes: 189 Episodic_Reweard: -186.0 Max_Reward_Achieved: -186.0
# Episodes: 190 Episodic_Reweard: -191.0 Max_Reward_Achieved: -186.0
# Episodes: 191 Episodic_Reweard: -191.0 Max_Reward_Achieved: -186.0
# Episodes: 192 Episodic_Reweard: -204.0 Max_Reward_Achieved: -186.0
# Episodes: 231 Episodic_Reweard: -144.0 Max_Reward_Achieved: -102.0
# Episodes: 232 Episodic_Reweard: -173.0 Max_Reward_Achieved: -102.0
# Episodes: 233 Episodic_Reweard: -151.0 Max_Reward_Achieved: -102.0
# Episodes: 234 Episodic_Reweard: -130.0 Max_Reward_Achieved: -102.0
# Episodes: 235 Episodic_Reweard: -117.0 Max_Reward_Achieved: -102.0
# Episodes: 236 Episodic_Reweard: -196.0 Max_Reward_Achieved: -102.0
# Episodes: 237 Episodic_Reweard: -184.0 Max_Reward_Achieved: -102.0
# Episodes: 238 Episodic_Reweard: -230.0 Max_Reward_Achieved: -102.0
# Episodes: 239 Episodic_Reweard: -182.0 Max_Reward_Achieved: -102.0
# Episodes: 240 Episodic_Reweard: -165.0 Max_Reward_Achieved: -102.0
# Episodes: 241 Episodic_Reweard: -154.0 Max_Reward_Achieved: -102.0
# Episodes: 242 Episodic_Reweard: -152.0 Max_Reward_Achieved: -102.0
# Episodes: 243 Episodic_Reweard: -147.0 Max_Reward_Achieved: -102.0
# Episodes: 244 Episodic_Reweard: -190.0 Max_Reward_Achieved: -102.0
# Episodes: 245 Episodic_Reweard: -160.0 Max_Reward_Achieved: -102.0
# Episodes: 246 Episodic_Reweard: -151.0 Max_Reward_Achieved: -102.0
# Episodes: 247 Episodic_Reweard: -176.0 Max_Reward_Achieved: -102.0
# Episodes: 248 Episodic_Reweard: -183.0 Max_Reward_Achieved: -102.0
# Episodes: 249 Episodic_Reweard: -118.0 Max_Reward_Achieved: -102.0
# Episodes: 250 Episodic_Reweard: -152.0 Max_Reward_Achieved: -102.0
# Episodes: 251 Episodic_Reweard: -129.0 Max_Reward_Achieved: -102.0
# Episodes: 252 Episodic_Reweard: -184.0 Max_Reward_Achieved: -102.0
# Episodes: 253 Episodic_Reweard: -170.0 Max_Reward_Achieved: -102.0
# Episodes: 254 Episodic_Reweard: -143.0 Max_Reward_Achieved: -102.0
# Episodes: 255 Episodic_Reweard: -202.0 Max_Reward_Achieved: -102.0
# Episodes: 256 Episodic_Reweard: -155.0 Max_Reward_Achieved: -102.0
# Episodes: 257 Episodic_Reweard: -128.0 Max_Reward_Achieved: -102.0
# Episodes: 258 Episodic_Reweard: -153.0 Max_Reward_Achieved: -102.0
# Episodes: 259 Episodic_Reweard: -124.0 Max_Reward_Achieved: -102.0
# Episodes: 260 Episodic_Reweard: -158.0 Max_Reward_Achieved: -102.0
# Episodes: 261 Episodic_Reweard: -144.0 Max_Reward_Achieved: -102.0
# Episodes: 262 Episodic_Reweard: -150.0 Max_Reward_Achieved: -102.0
# Episodes: 263 Episodic_Reweard: -172.0 Max_Reward_Achieved: -102.0
# Episodes: 264 Episodic_Reweard: -126.0 Max_Reward_Achieved: -102.0
# Episodes: 265 Episodic_Reweard: -128.0 Max_Reward_Achieved: -102.0
# Episodes: 266 Episodic_Reweard: -125.0 Max_Reward_Achieved: -102.0
# Episodes: 267 Episodic_Reweard: -166.0 Max_Reward_Achieved: -102.0
# Episodes: 268 Episodic_Reweard: -176.0 Max_Reward_Achieved: -102.0
# Episodes: 269 Episodic_Reweard: -131.0 Max_Reward_Achieved: -102.0
# Episodes: 270 Episodic_Reweard: -186.0 Max_Reward_Achieved: -102.0
# Episodes: 271 Episodic_Reweard: -133.0 Max_Reward_Achieved: -102.0
# Episodes: 272 Episodic_Reweard: -163.0 Max_Reward_Achieved: -102.0
# Episodes: 273 Episodic_Reweard: -160.0 Max_Reward_Achieved: -102.0
# Episodes: 274 Episodic_Reweard: -156.0 Max_Reward_Achieved: -102.0
# Episodes: 275 Episodic_Reweard: -184.0 Max_Reward_Achieved: -102.0
# Episodes: 276 Episodic_Reweard: -159.0 Max_Reward_Achieved: -102.0
# Episodes: 277 Episodic_Reweard: -141.0 Max_Reward_Achieved: -102.0
# Episodes: 278 Episodic_Reweard: -214.0 Max_Reward_Achieved: -102.0
# Episodes: 279 Episodic_Reweard: -121.0 Max_Reward_Achieved: -102.0
# Episodes: 280 Episodic_Reweard: -178.0 Max_Reward_Achieved: -102.0
# Episodes: 281 Episodic_Reweard: -159.0 Max_Reward_Achieved: -102.0
# Episodes: 282 Episodic_Reweard: -169.0 Max_Reward_Achieved: -102.0
# Episodes: 283 Episodic_Reweard: -142.0 Max_Reward_Achieved: -102.0
# Episodes: 284 Episodic_Reweard: -187.0 Max_Reward_Achieved: -102.0
# Episodes: 285 Episodic_Reweard: -124.0 Max_Reward_Achieved: -102.0
# Episodes: 286 Episodic_Reweard: -135.0 Max_Reward_Achieved: -102.0
# Episodes: 287 Episodic_Reweard: -194.0 Max_Reward_Achieved: -102.0
# Episodes: 288 Episodic_Reweard: -140.0 Max_Reward_Achieved: -102.0
# Episodes: 289 Episodic_Reweard: -123.0 Max_Reward_Achieved: -102.0
# Episodes: 290 Episodic_Reweard: -142.0 Max_Reward_Achieved: -102.0
# Episodes: 291 Episodic_Reweard: -115.0 Max_Reward_Achieved: -102.0
# Episodes: 292 Episodic_Reweard: -124.0 Max_Reward_Achieved: -102.0
# Episodes: 293 Episodic_Reweard: -132.0 Max_Reward_Achieved: -102.0
# Episodes: 294 Episodic_Reweard: -176.0 Max_Reward_Achieved: -102.0
# Episodes: 295 Episodic_Reweard: -220.0 Max_Reward_Achieved: -102.0
# Episodes: 296 Episodic_Reweard: -103.0 Max_Reward_Achieved: -102.0
# Episodes: 297 Episodic_Reweard: -92.0 Max_Reward_Achieved: -92.0
# Episodes: 298 Episodic_Reweard: -132.0 Max_Reward_Achieved: -92.0
# Episodes: 299 Episodic_Reweard: -138.0 Max_Reward_Achieved: -92.0
# Episodes: 300 Episodic_Reweard: -140.0 Max_Reward_Achieved: -92.0
# Episodes: 301 Episodic_Reweard: -204.0 Max_Reward_Achieved: -92.0
# Episodes: 302 Episodic_Reweard: -172.0 Max_Reward_Achieved: -92.0
# Episodes: 303 Episodic_Reweard: -125.0 Max_Reward_Achieved: -92.0
# Episodes: 304 Episodic_Reweard: -374.0 Max_Reward_Achieved: -92.0
# Episodes: 305 Episodic_Reweard: -272.0 Max_Reward_Achieved: -92.0
# Episodes: 306 Episodic_Reweard: -164.0 Max_Reward_Achieved: -92.0
# Episodes: 383 Episodic_Reweard: -136.0 Max_Reward_Achieved: -92.0
# Episodes: 384 Episodic_Reweard: -182.0 Max_Reward_Achieved: -92.0
# Episodes: 385 Episodic_Reweard: -112.0 Max_Reward_Achieved: -92.0
# Episodes: 386 Episodic_Reweard: -132.0 Max_Reward_Achieved: -92.0
# Episodes: 387 Episodic_Reweard: -77.0 Max_Reward_Achieved: -77.0
# Episodes: 388 Episodic_Reweard: -106.0 Max_Reward_Achieved: -77.0
# Episodes: 389 Episodic_Reweard: -103.0 Max_Reward_Achieved: -77.0
# Episodes: 390 Episodic_Reweard: -110.0 Max_Reward_Achieved: -77.0
# Episodes: 391 Episodic_Reweard: -104.0 Max_Reward_Achieved: -77.0
# Episodes: 392 Episodic_Reweard: -210.0 Max_Reward_Achieved: -77.0
# Episodes: 393 Episodic_Reweard: -114.0 Max_Reward_Achieved: -77.0
# Episodes: 394 Episodic_Reweard: -109.0 Max_Reward_Achieved: -77.0
# Episodes: 395 Episodic_Reweard: -95.0 Max_Reward_Achieved: -77.0
# Episodes: 396 Episodic_Reweard: -179.0 Max_Reward_Achieved: -77.0
# Episodes: 397 Episodic_Reweard: -118.0 Max_Reward_Achieved: -77.0
# Episodes: 398 Episodic_Reweard: -139.0 Max_Reward_Achieved: -77.0
# Episodes: 399 Episodic_Reweard: -89.0 Max_Reward_Achieved: -77.0
# Episodes: 400 Episodic_Reweard: -121.0 Max_Reward_Achieved: -77.0
# Episodes: 401 Episodic_Reweard: -97.0 Max_Reward_Achieved: -77.0
# Episodes: 402 Episodic_Reweard: -106.0 Max_Reward_Achieved: -77.0
# Episodes: 403 Episodic_Reweard: -86.0 Max_Reward_Achieved: -77.0
# Episodes: 404 Episodic_Reweard: -123.0 Max_Reward_Achieved: -77.0
# Episodes: 405 Episodic_Reweard: -124.0 Max_Reward_Achieved: -77.0
# Episodes: 406 Episodic_Reweard: -118.0 Max_Reward_Achieved: -77.0
# Episodes: 407 Episodic_Reweard: -107.0 Max_Reward_Achieved: -77.0
# Episodes: 408 Episodic_Reweard: -98.0 Max_Reward_Achieved: -77.0
# Episodes: 409 Episodic_Reweard: -111.0 Max_Reward_Achieved: -77.0
# Episodes: 410 Episodic_Reweard: -101.0 Max_Reward_Achieved: -77.0
# Episodes: 411 Episodic_Reweard: -113.0 Max_Reward_Achieved: -77.0
# Episodes: 412 Episodic_Reweard: -99.0 Max_Reward_Achieved: -77.0
# Episodes: 413 Episodic_Reweard: -98.0 Max_Reward_Achieved: -77.0
# Episodes: 414 Episodic_Reweard: -94.0 Max_Reward_Achieved: -77.0
# Episodes: 415 Episodic_Reweard: -107.0 Max_Reward_Achieved: -77.0
# Episodes: 416 Episodic_Reweard: -84.0 Max_Reward_Achieved: -77.0
# Episodes: 417 Episodic_Reweard: -96.0 Max_Reward_Achieved: -77.0
# Episodes: 418 Episodic_Reweard: -87.0 Max_Reward_Achieved: -77.0
# Episodes: 419 Episodic_Reweard: -102.0 Max_Reward_Achieved: -77.0
# Episodes: 420 Episodic_Reweard: -108.0 Max_Reward_Achieved: -77.0
# Episodes: 421 Episodic_Reweard: -87.0 Max_Reward_Achieved: -77.0
# Episodes: 422 Episodic_Reweard: -99.0 Max_Reward_Achieved: -77.0
# Episodes: 423 Episodic_Reweard: -173.0 Max_Reward_Achieved: -77.0
# Episodes: 424 Episodic_Reweard: -79.0 Max_Reward_Achieved: -77.0
# Episodes: 425 Episodic_Reweard: -101.0 Max_Reward_Achieved: -77.0
# Episodes: 426 Episodic_Reweard: -82.0 Max_Reward_Achieved: -77.0
# Episodes: 427 Episodic_Reweard: -82.0 Max_Reward_Achieved: -77.0
# Episodes: 428 Episodic_Reweard: -99.0 Max_Reward_Achieved: -77.0
# Episodes: 429 Episodic_Reweard: -126.0 Max_Reward_Achieved: -77.0
# Episodes: 430 Episodic_Reweard: -81.0 Max_Reward_Achieved: -77.0
# Episodes: 431 Episodic_Reweard: -97.0 Max_Reward_Achieved: -77.0
# Episodes: 432 Episodic_Reweard: -100.0 Max_Reward_Achieved: -77.0
# Episodes: 433 Episodic_Reweard: -78.0 Max_Reward_Achieved: -77.0
# Episodes: 434 Episodic_Reweard: -82.0 Max_Reward_Achieved: -77.0
# Episodes: 435 Episodic_Reweard: -98.0 Max_Reward_Achieved: -77.0
# Episodes: 436 Episodic_Reweard: -89.0 Max_Reward_Achieved: -77.0
# Episodes: 437 Episodic_Reweard: -87.0 Max_Reward_Achieved: -77.0
# Episodes: 438 Episodic_Reweard: -108.0 Max_Reward_Achieved: -77.0
# Episodes: 439 Episodic_Reweard: -159.0 Max_Reward_Achieved: -77.0
# Episodes: 440 Episodic_Reweard: -85.0 Max_Reward_Achieved: -77.0
# Episodes: 441 Episodic_Reweard: -82.0 Max_Reward_Achieved: -77.0
# Episodes: 442 Episodic_Reweard: -84.0 Max_Reward_Achieved: -77.0
# Episodes: 443 Episodic_Reweard: -97.0 Max_Reward_Achieved: -77.0
# Episodes: 444 Episodic_Reweard: -93.0 Max_Reward_Achieved: -77.0
# Episodes: 445 Episodic_Reweard: -84.0 Max_Reward_Achieved: -77.0
# Episodes: 446 Episodic_Reweard: -76.0 Max_Reward_Achieved: -76.0
# Episodes: 447 Episodic_Reweard: -76.0 Max_Reward_Achieved: -76.0
# Episodes: 448 Episodic_Reweard: -94.0 Max_Reward_Achieved: -76.0
# Episodes: 449 Episodic_Reweard: -81.0 Max_Reward_Achieved: -76.0
# Episodes: 450 Episodic_Reweard: -100.0 Max_Reward_Achieved: -76.0
# Episodes: 451 Episodic_Reweard: -77.0 Max_Reward_Achieved: -76.0
# Episodes: 452 Episodic_Reweard: -91.0 Max_Reward_Achieved: -76.0
# Episodes: 453 Episodic_Reweard: -81.0 Max_Reward_Achieved: -76.0
# Episodes: 454 Episodic_Reweard: -99.0 Max_Reward_Achieved: -76.0
# Episodes: 455 Episodic_Reweard: -90.0 Max_Reward_Achieved: -76.0
# Episodes: 456 Episodic_Reweard: -81.0 Max_Reward_Achieved: -76.0
# Episodes: 457 Episodic_Reweard: -134.0 Max_Reward_Achieved: -76.0
#
# Environment solved in 358 episodes!	Average Score: -109.21
